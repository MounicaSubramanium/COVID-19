# %% [markdown]
# Looking at the Hopkins COVID-19 data that was cloned from https://github.com/CSSEGISandData/COVID-19

# %%
# API calls for the global data

# %%
import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

# Loading initial Hopkins gloval time series data
df_confirmed = pd.read_csv('./csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
# Reading API key

api_file = open('key.txt', 'r')
API_KEY = api_file.read()
api_file.close()
API_KEY = API_KEY.strip()

# %%
df_confirmed.head()

# %%
df_confirmed.info()

# %% [markdown]
# I think I just need to work with the confirmed DataFrame. It's set up such that each row is a specific location, and the columns are different dates.

# %%
#creating template for dataframes to record various values

df_template = df_confirmed.copy()


df_template.head(), df_template.size

# %%
# Creating template out of JHU table format

do_not_include = ['Province/State', 'Country/Region', 'Lat', 'Long']

for x in df_template.columns.values:
    if (x not in do_not_include):
        for y in range(df_template['8/3/20'].values.size):
            df_template.at[y, x] = -10000
            
            
df_template.head()

# %%
# Adding the rest of the beginning of January

for q in range(1, 22):
    day_str = str(q)
    date_str = '1/' + day_str + '/20'
    df_template[date_str] = -10000    

df_template.head()

# %%
df_template.columns.values

# %%
# Rearranging date columns to be in chronological order

ordered_columns = ['Province/State', 'Country/Region', 'Lat', 'Long', '1/1/20',
                   '1/2/20', '1/3/20', '1/4/20', '1/5/20', '1/6/20', '1/7/20', 
                   '1/8/20', '1/9/20', '1/10/20', '1/11/20', '1/12/20', 
                   '1/13/20', '1/14/20', '1/15/20', '1/16/20', '1/17/20', 
                   '1/18/20', '1/19/20', '1/20/20', '1/21/20', '1/22/20', 
                   '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', 
                   '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', 
                   '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', 
                   '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', 
                   '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', 
                   '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', 
                   '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', 
                   '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', 
                   '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', 
                   '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20',
                   '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', 
                   '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', 
                   '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', 
                   '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', 
                   '4/10/20', '4/11/20', '4/12/20', '4/14/20', '4/15/20', '4/16/20',
                   '4/17/20', '4/18/20', '4/19/20', '4/20/20', '4/21/20', '4/22/20', 
                   '4/23/20', '4/24/20', '4/25/20', '4/26/20', '4/27/20', '4/28/20', 
                   '4/29/20', '4/30/20', '5/1/20', '5/2/20', '5/3/20', '5/4/20', 
                   '5/5/20', '5/6/20', '5/7/20', '5/8/20', '5/9/20', '5/10/20', 
                   '5/11/20', '5/12/20', '5/13/20', '5/14/20', '5/15/20', '5/16/20',
                   '5/17/20', '5/18/20', '5/19/20', '5/20/20', '5/21/20', '5/22/20', 
                   '5/23/20', '5/24/20', '5/25/20', '5/26/20', '5/27/20', '5/28/20', 
                   '5/29/20', '5/30/20', '5/31/20', '6/1/20', '6/2/20', '6/3/20', 
                   '6/4/20', '6/5/20', '6/6/20', '6/7/20', '6/8/20', '6/9/20', 
                   '6/10/20', '6/11/20', '6/12/20', '6/13/20', '6/14/20', '6/15/20', 
                   '6/16/20', '6/17/20', '6/18/20', '6/19/20', '6/20/20', '6/21/20', 
                   '6/22/20', '6/23/20', '6/24/20', '6/25/20', '6/26/20', '6/27/20', 
                   '6/28/20', '6/29/20', '6/30/20', '7/1/20', '7/2/20', '7/3/20', 
                   '7/4/20', '7/5/20', '7/6/20', '7/7/20', '7/8/20', '7/9/20', 
                   '7/10/20', '7/11/20', '7/12/20', '7/13/20', '7/14/20', '7/15/20', 
                   '7/16/20', '7/17/20', '7/18/20', '7/19/20', '7/20/20', '7/21/20', 
                   '7/22/20', '7/23/20', '7/24/20', '7/25/20', '7/26/20', '7/27/20', 
                   '7/28/20', '7/29/20', '7/30/20', '7/31/20', '8/1/20', '8/2/20', 
                   '8/3/20', '8/4/20', '8/5/20', '8/6/20', '8/7/20', '8/8/20', 
                   '8/9/20', '8/10/20', '8/11/20', '8/12/20']

df_template = df_template[ordered_columns]

df_template.head()

# %%
df_template.info()

# %%
# For description of the different units being captured from the API,
# please see https://darksky.net/dev/docs
# Requests are being made in SI units

# dataframe to record median maximum temperature
df_tMax = df_template.copy()

# dataframe to record median minimum temperature
df_tMin = df_template.copy()

# dataframe to record median humidity
df_humidity = df_template.copy()

# dataframe to record median UV index
df_uvIndex = df_template.copy()

# dataframe to record median cloud cover
df_cloud = df_template.copy()

# dataframe to record weather summaries
#df_summaries = df_template.copy()

# dataframe to record precipitation probability
df_precipprob = df_template.copy()

# dataframe to record dewpoint
df_dewpoint = df_template.copy()

# dataframe to record pressure
df_pressure = df_template.copy()

# dataframe to record windspeed
df_windspeed = df_template.copy()

# dataframe to record "ozone" reading
df_ozone = df_template.copy()

# dataframe to record sunrise time
df_sunrise = df_template.copy()

# dataframe to record sunset time
df_sunset = df_template.copy()

# %%
df_tMax.head()

# %%
# Creating initial CSV files

df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
df_sunset.to_csv('./csv/sunset_Global.csv', index=False)

# %%
# If resuming, start from below

# %%
import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

# reading CSV files to create dataframes
df_tMax = pd.read_csv('./csv/tMax_Global.csv')
df_tMin = pd.read_csv('./csv/tMin_Global.csv')
df_humidity = pd.read_csv('./csv/humidity_Global.csv')
df_uvIndex = pd.read_csv('./csv/uv_Global.csv')
df_cloud = pd.read_csv('./csv/cloud_Global.csv')
df_precipprob = pd.read_csv('./csv/precip_Global.csv')
df_dewpoint = pd.read_csv('./csv/dew_Global.csv')
df_pressure = pd.read_csv('./csv/pressure_Global.csv')
df_windspeed = pd.read_csv('./csv/wind_Global.csv')
df_ozone = pd.read_csv('./csv/ozone_Global.csv')
df_sunrise = pd.read_csv('./csv/sunrise_Global.csv')
df_sunset = pd.read_csv('./csv/sunset_Global.csv')

# %%
df_sunset.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/1/20  1/2/20  1/3/20  \
# 0            NaN    Afghanistan  33.93911  67.709953  -10000  -10000  -10000
# 1            NaN        Albania  41.15330  20.168300  -10000  -10000  -10000
# 2            NaN        Algeria  28.03390   1.659600  -10000  -10000  -10000
# 3            NaN        Andorra  42.50630   1.521800  -10000  -10000  -10000
# 4            NaN         Angola -11.20270  17.873900  -10000  -10000  -10000
#
#    1/4/20  1/5/20  1/6/20  ...  8/3/20  8/4/20  8/5/20  8/6/20  8/7/20  \
# 0  -10000  -10000  -10000  ...   36747   36782   36829   36896   37015
# 1  -10000  -10000  -10000  ...    5620    5750    5889    6016    6151
# 2  -10000  -10000  -10000  ...   31972   32504   33055   33626   34155
# 3  -10000  -10000  -10000  ...     937     939     939     944     955
# 4  -10000  -10000  -10000  ...    1280    1344    1395    1483    1538
#
#    8/8/20  8/9/20  8/10/20  8/11/20  8/12/20
# 0   37054   37054    37162    37269    37345
# 1    6275    6411     6536     6676     6817
# 2   34693   35160    35712    36204    36699
# 3     955     955      963      963      977
# 4    1572    1672     1679     1735     1762
#
# [5 rows x 228 columns]

# %%
# Reading API key

api_file = open('key.txt', 'r')
API_KEY = api_file.read()
api_file.close()
API_KEY = API_KEY.strip()

# %%
# Resuming the API calls

# Code to increase number of retries on connection errors,
# and also to give it some time.
# Found on https://stackoverflow.com/questions/15431044/can-i-set-max-retries-for-requests-request
# And https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

s = requests.Session()

retries = Retry(total=30,
                backoff_factor=0.1,
                status_forcelist=[ 429, 500, 502, 503, 504 ],
                method_whitelist=["HEAD", "GET", "OPTIONS"])

adapter = HTTPAdapter(max_retries=retries)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)

# pull data from darksky weather API

# Columns to be skipped when iterating through the DataFrame
do_not_include = ['Province/State', 'Country/Region', 'Lat', 'Long']

# counter
counter = 0

# Dummy value in case of errors
dummy = -1000

# variable for determining how many API calls between writing data to CSV
write_var = 1000

# Start iterating through the date columns
for x in df_tMax.columns.values:
    
    # Skip the columns that are not dates
    if (x not in do_not_include):
        
        # Create Unix time stamp out of the date column
        t = pd.to_datetime(df_tMax[x].name)
        t = int(t.value / 10**9)
        t = str(t)
                
        # Start iterating through the rows (locations)
        for y in range(df_tMax['1/22/20'].values.size):
            
            # Only do API call if the cell value is 0
            if str(df_tMax.iloc[y][x]) == '-10000':
                
                print('Cell is -10000')
                
                # latitude and longitude coordinates of the row to be passed to the API            
                latitude = str(df_tMax.iloc[y][2])
                longitude = str(df_tMax.iloc[y][3])

                print('Coordinates: ', latitude, ',', longitude)
                
                # Building the URL for the API get
                url = 'https://api.darksky.net/forecast/' + API_KEY + '/' + latitude + "," + longitude + ',' + t
                url = url + '?exclude=currently,flags&units=si'

                # Getting the API call
                # using the retry error handling established above
                response = http.get(url)
                
                # Putting the API response into the JSON thing
                info = json.loads(response.content)

                # adding error handling in case something is wrong with the JSON response
                try:

                    # Making a variable to more easily acccess JSON response data
                    easy_info = info['daily']['data'][0]

                    # Reading the JSON data
                    tMax = easy_info['temperatureHigh']
                    tMin = easy_info['temperatureLow']
                    hum = easy_info['humidity'] * 100
                    uvee = easy_info['uvIndex']
                    clouds = easy_info['cloudCover'] * 100
                    precip = easy_info['precipProbability'] * 100
                    dew = easy_info['dewPoint']
                    pressure = easy_info['pressure']
                    wind = easy_info['windSpeed']
                    ozone = easy_info['ozone']
                    sunrise = easy_info['sunriseTime']
                    sunset = easy_info['sunsetTime']

                except:

                    # Creating dummy values in case of error
                    print('Error encountered')
                    tMax = dummy
                    tMin = dummy
                    hum = dummy
                    uvee = dummy
                    clouds = dummy
                    precip = dummy
                    dew = dummy
                    pressure = dummy
                    wind = dummy
                    ozone = dummy
                    sunrise = dummy
                    sunset = dummy

                # Recording the data into the respective dataframes
                df_tMax.at[y, x] = tMax
                df_tMin.at[y, x] = tMin
                df_humidity.at[y, x] = hum
                df_uvIndex.at[y, x] = uvee
                df_cloud.at[y, x] = clouds
                df_precipprob.at[y, x] = precip
                df_dewpoint.at[y, x] = dew
                df_pressure.at[y, x] = pressure
                df_windspeed.at[y, x] = wind
                df_ozone.at[y, x] = ozone
                df_sunrise.at[y,x] = sunrise
                df_sunset.at[y,x] = sunset
            
            counter = counter + 1
            print(counter)

            # writing CSVs of what I've got so far, for every write_var API calls
            if counter % write_var == 0:
                
                print('1000 API calls')
                df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
                df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
                df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
                df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
                df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
                df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
                df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
                df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
                df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
                df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
                df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
                df_sunset.to_csv('./csv/sunset_Global.csv', index=False)

# Writing final data to csv
print('Final data write')
df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
df_sunset.to_csv('./csv/sunset_Global.csv', index=False)
# Out:
# Cell is -10000
# Coordinates:  33.93911 , 67.709953
# 1
# Cell is -10000
# Coordinates:  41.1533 , 20.1683
# 2
# Cell is -10000
# Coordinates:  28.0339 , 1.6596
# 3
# Cell is -10000
# Coordinates:  42.5063 , 1.5218
# 4
# Cell is -10000
# Coordinates:  -11.2027 , 17.8739
# 5
# Cell is -10000
# Coordinates:  17.0608 , -61.7964
# 6
# Cell is -10000
# Coordinates:  -38.4161 , -63.6167
# 7
# Cell is -10000
# Coordinates:  40.0691 , 45.0382
# 8
# Cell is -10000
# Coordinates:  -35.4735 , 149.0124
# 9
# Cell is -10000
# Coordinates:  -33.8688 , 151.2093
# 10
# Cell is -10000
# Coordinates:  -12.4634 , 130.8456
# 11
# Cell is -10000
# Coordinates:  -27.4698 , 153.0251
# 12
# Cell is -10000
# Coordinates:  -34.9285 , 138.6007
# 13
# Cell is -10000
# Coordinates:  -42.8821 , 147.3272
# 14
# Cell is -10000
# Coordinates:  -37.8136 , 144.9631
# 15
# Cell is -10000
# Coordinates:  -31.9505 , 115.8605
# 16
# Cell is -10000
# Coordinates:  47.5162 , 14.5501
# 17
# Cell is -10000
# Coordinates:  40.1431 , 47.5769
# 18
# Cell is -10000
# Coordinates:  25.025885 , -78.035889
# 19
# Cell is -10000
# Coordinates:  26.0275 , 50.55
# 20
# Cell is -10000
# Coordinates:  23.685 , 90.3563
# 21
# Cell is -10000
# Coordinates:  13.1939 , -59.5432
# 22
# Cell is -10000
# Coordinates:  53.7098 , 27.9534
# 23
# Cell is -10000
# Coordinates:  50.8333 , 4.469936
# 24
# Cell is -10000
# Coordinates:  17.1899 , -88.4976
# 25
# Cell is -10000
# Coordinates:  9.3077 , 2.3158
# 26
# Cell is -10000
# Coordinates:  27.5142 , 90.4336
# 27
# Cell is -10000
# Coordinates:  -16.2902 , -63.5887
# 28
# Cell is -10000
# Coordinates:  43.9159 , 17.6791
# 29
# Cell is -10000
# Coordinates:  -22.3285 , 24.6849
# 30
# Cell is -10000
# Coordinates:  -14.235 , -51.9253
# 31
# Cell is -10000
# Coordinates:  4.5353 , 114.7277
# 32
# Cell is -10000
# Coordinates:  42.7339 , 25.4858
# 33
# Cell is -10000
# Coordinates:  12.2383 , -1.5616
# 34
# Cell is -10000
# Coordinates:  21.9162 , 95.956
# 35
# Cell is -10000
# Coordinates:  -3.3731 , 29.9189
# 36
# Cell is -10000
# Coordinates:  16.5388 , -23.0418
# 37
# Cell is -10000
# Coordinates:  11.55 , 104.9167
# 38
# Cell is -10000
# Coordinates:  3.848 , 11.5021
# 39
# Cell is -10000
# Coordinates:  53.9333 , -116.5765
# 40
# Cell is -10000
# Coordinates:  53.7267 , -127.6476
# 41
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 42
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 43
# Cell is -10000
# Coordinates:  53.7609 , -98.8139
# 44
# Cell is -10000
# Coordinates:  46.5653 , -66.4619
# 45
# Cell is -10000
# Coordinates:  53.1355 , -57.6604
# 46
# Cell is -10000
# Coordinates:  64.8255 , -124.8457
# 47
# Cell is -10000
# Coordinates:  44.682 , -63.7443
# 48
# Cell is -10000
# Coordinates:  51.2538 , -85.3232
# 49
# Cell is -10000
# Coordinates:  46.5107 , -63.4168
# 50
# Cell is -10000
# Coordinates:  52.9399 , -73.5491
# 51
# Cell is -10000
# Coordinates:  52.9399 , -106.4509
# 52
# Cell is -10000
# Coordinates:  64.2823 , -135.0
# 53
# Cell is -10000
# Coordinates:  6.6111 , 20.9394
# 54
# Cell is -10000
# Coordinates:  15.4542 , 18.7322
# 55
# Cell is -10000
# Coordinates:  -35.6751 , -71.543
# 56
# Cell is -10000
# Coordinates:  31.8257 , 117.2264
# 57
# Cell is -10000
# Coordinates:  40.1824 , 116.4142
# 58
# Cell is -10000
# Coordinates:  30.0572 , 107.874
# 59
# Cell is -10000
# Coordinates:  26.0789 , 117.9874
# 60
# Cell is -10000
# Coordinates:  35.7518 , 104.2861
# 61
# Cell is -10000
# Coordinates:  23.3417 , 113.4244
# 62
# Cell is -10000
# Coordinates:  23.8298 , 108.7881
# 63
# Cell is -10000
# Coordinates:  26.8154 , 106.8748
# 64
# Cell is -10000
# Coordinates:  19.1959 , 109.7453
# 65
# Cell is -10000
# Coordinates:  39.549 , 116.1306
# 66
# Cell is -10000
# Coordinates:  47.862 , 127.7615
# 67
# Cell is -10000
# Coordinates:  37.8957 , 114.9042
# 68
# Cell is -10000
# Coordinates:  22.3 , 114.2
# 69
# Cell is -10000
# Coordinates:  30.9756 , 112.2707
# 70
# Cell is -10000
# Coordinates:  27.6104 , 111.7088
# 71
# Cell is -10000
# Coordinates:  44.0935 , 113.9448
# 72
# Cell is -10000
# Coordinates:  32.9711 , 119.455
# 73
# Cell is -10000
# Coordinates:  27.614 , 115.7221
# 74
# Cell is -10000
# Coordinates:  43.6661 , 126.1923
# 75
# Cell is -10000
# Coordinates:  41.2956 , 122.6085
# 76
# Cell is -10000
# Coordinates:  22.1667 , 113.55
# 77
# Cell is -10000
# Coordinates:  37.2692 , 106.1655
# 78
# Cell is -10000
# Coordinates:  35.7452 , 95.9956
# 79
# Cell is -10000
# Coordinates:  35.1917 , 108.8701
# 80
# Cell is -10000
# Coordinates:  36.3427 , 118.1498
# 81
# Cell is -10000
# Coordinates:  31.202 , 121.4491
# 82
# Cell is -10000
# Coordinates:  37.5777 , 112.2922
# 83
# Cell is -10000
# Coordinates:  30.6171 , 102.7103
# 84
# Cell is -10000
# Coordinates:  39.3054 , 117.323
# 85
# Cell is -10000
# Coordinates:  31.6927 , 88.0924
# 86
# Cell is -10000
# Coordinates:  41.1129 , 85.2401
# 87
# Cell is -10000
# Coordinates:  24.974 , 101.487
# 88
# Cell is -10000
# Coordinates:  29.1832 , 120.0934
# 89
# Cell is -10000
# Coordinates:  4.5709 , -74.2973
# 90
# Cell is -10000
# Coordinates:  -11.6455 , 43.3333
# 91
# Cell is -10000
# Coordinates:  -0.228 , 15.8277
# 92
# Cell is -10000
# Coordinates:  -4.0383 , 21.7587
# 93
# Cell is -10000
# Coordinates:  9.7489 , -83.7534
# 94
# Cell is -10000
# Coordinates:  7.54 , -5.5471
# 95
# Cell is -10000
# Coordinates:  45.1 , 15.2
# 96
# Cell is -10000
# Coordinates:  21.521757 , -77.78116700000002
# 97
# Cell is -10000
# Coordinates:  35.1264 , 33.4299
# 98
# Cell is -10000
# Coordinates:  49.8175 , 15.473
# 99
# Cell is -10000
# Coordinates:  61.8926 , -6.9118
# 100
# Cell is -10000
# Coordinates:  71.7069 , -42.6043
# Error encountered
# 101
# Cell is -10000
# Coordinates:  56.2639 , 9.5018
# 102
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 103
# Cell is -10000
# Coordinates:  11.8251 , 42.5903
# 104
# Cell is -10000
# Coordinates:  15.415 , -61.371
# 105
# Cell is -10000
# Coordinates:  18.7357 , -70.1627
# 106
# Cell is -10000
# Coordinates:  -1.8312 , -78.1834
# 107
# Cell is -10000
# Coordinates:  26.820553000000004 , 30.802498
# 108
# Cell is -10000
# Coordinates:  13.7942 , -88.8965
# 109
# Cell is -10000
# Coordinates:  1.6508 , 10.2679
# 110
# Cell is -10000
# Coordinates:  15.1794 , 39.7823
# 111
# Cell is -10000
# Coordinates:  58.5953 , 25.0136
# 112
# Cell is -10000
# Coordinates:  -26.5225 , 31.4659
# 113
# Cell is -10000
# Coordinates:  9.145 , 40.4897
# 114
# Cell is -10000
# Coordinates:  -17.7134 , 178.065
# 115
# Cell is -10000
# Coordinates:  61.92411 , 25.748151
# 116
# Cell is -10000
# Coordinates:  3.9339 , -53.1258
# 117
# Cell is -10000
# Coordinates:  -17.6797 , 149.4068
# 118
# Cell is -10000
# Coordinates:  16.265 , -61.551
# 119
# Cell is -10000
# Coordinates:  14.6415 , -61.0242
# 120
# Cell is -10000
# Coordinates:  -12.8275 , 45.166244
# 121
# Cell is -10000
# Coordinates:  -20.904305 , 165.618042
# 122
# Cell is -10000
# Coordinates:  -21.1151 , 55.5364
# 123
# Cell is -10000
# Coordinates:  17.9 , -62.8333
# 124
# Cell is -10000
# Coordinates:  46.8852 , -56.3159
# 125
# Cell is -10000
# Coordinates:  18.0708 , -63.0501
# 126
# Cell is -10000
# Coordinates:  46.2276 , 2.2137
# 127
# Cell is -10000
# Coordinates:  -0.8037 , 11.6094
# 128
# Cell is -10000
# Coordinates:  13.4432 , -15.3101
# 129
# Cell is -10000
# Coordinates:  42.3154 , 43.3569
# 130
# Cell is -10000
# Coordinates:  51.165691 , 10.451526
# 131
# Cell is -10000
# Coordinates:  7.9465 , -1.0232
# 132
# Cell is -10000
# Coordinates:  39.0742 , 21.8243
# 133
# Cell is -10000
# Coordinates:  12.1165 , -61.679
# 134
# Cell is -10000
# Coordinates:  15.7835 , -90.2308
# 135
# Cell is -10000
# Coordinates:  9.9456 , -9.6966
# 136
# Cell is -10000
# Coordinates:  11.8037 , -15.1804
# 137
# Cell is -10000
# Coordinates:  4.860416000000002 , -58.93018000000001
# 138
# Cell is -10000
# Coordinates:  18.9712 , -72.2852
# 139
# Cell is -10000
# Coordinates:  41.9029 , 12.4534
# 140
# Cell is -10000
# Coordinates:  15.2 , -86.2419
# 141
# Cell is -10000
# Coordinates:  47.1625 , 19.5033
# 142
# Cell is -10000
# Coordinates:  64.9631 , -19.0208
# 143
# Cell is -10000
# Coordinates:  20.593684 , 78.96288
# 144
# Cell is -10000
# Coordinates:  -0.7893 , 113.9213
# 145
# Cell is -10000
# Coordinates:  32.427908 , 53.68804599999999
# 146
# Cell is -10000
# Coordinates:  33.223191 , 43.679291
# 147
# Cell is -10000
# Coordinates:  53.1424 , -7.6921
# 148
# Cell is -10000
# Coordinates:  31.046051 , 34.851612
# 149
# Cell is -10000
# Coordinates:  41.87194 , 12.56738
# 150
# Cell is -10000
# Coordinates:  18.1096 , -77.2975
# 151
# Cell is -10000
# Coordinates:  36.204824 , 138.252924
# 152
# Cell is -10000
# Coordinates:  31.24 , 36.51
# 153
# Cell is -10000
# Coordinates:  48.0196 , 66.9237
# 154
# Cell is -10000
# Coordinates:  -0.0236 , 37.9062
# 155
# Cell is -10000
# Coordinates:  35.90775700000001 , 127.766922
# 156
# Cell is -10000
# Coordinates:  42.602636 , 20.902977
# 157
# Cell is -10000
# Coordinates:  29.31166 , 47.481766
# 158
# Cell is -10000
# Coordinates:  41.20438 , 74.766098
# 159
# Cell is -10000
# Coordinates:  19.85627 , 102.495496
# 160
# Cell is -10000
# Coordinates:  56.8796 , 24.6032
# 161
# Cell is -10000
# Coordinates:  33.8547 , 35.8623
# 162
# Cell is -10000
# Coordinates:  -29.61 , 28.2336
# 163
# Cell is -10000
# Coordinates:  6.4280550000000005 , -9.429499
# 164
# Cell is -10000
# Coordinates:  26.3351 , 17.228331
# 165
# Cell is -10000
# Coordinates:  47.14 , 9.55
# 166
# Cell is -10000
# Coordinates:  55.1694 , 23.8813
# 167
# Cell is -10000
# Coordinates:  49.8153 , 6.1296
# 168
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 169
# Cell is -10000
# Coordinates:  -18.766947 , 46.869107
# 170
# Cell is -10000
# Coordinates:  -13.2543 , 34.3015
# 171
# Cell is -10000
# Coordinates:  4.210483999999999 , 101.975766
# 172
# Cell is -10000
# Coordinates:  3.2028 , 73.2207
# 173
# Cell is -10000
# Coordinates:  17.570692 , -3.996166000000001
# 174
# Cell is -10000
# Coordinates:  35.9375 , 14.3754
# 175
# Cell is -10000
# Coordinates:  21.0079 , -10.9408
# 176
# Cell is -10000
# Coordinates:  -20.348404 , 57.552152
# 177
# Cell is -10000
# Coordinates:  23.6345 , -102.5528
# 178
# Cell is -10000
# Coordinates:  47.4116 , 28.3699
# 179
# Cell is -10000
# Coordinates:  43.7333 , 7.4167
# 180
# Cell is -10000
# Coordinates:  46.8625 , 103.8467
# 181
# Cell is -10000
# Coordinates:  42.708678000000006 , 19.37439
# 182
# Cell is -10000
# Coordinates:  31.7917 , -7.0926
# 183
# Cell is -10000
# Coordinates:  -18.665695 , 35.529562
# 184
# Cell is -10000
# Coordinates:  -22.9576 , 18.4904
# 185
# Cell is -10000
# Coordinates:  28.1667 , 84.25
# 186
# Cell is -10000
# Coordinates:  12.5211 , -69.9683
# 187
# Cell is -10000
# Coordinates:  12.1784 , -68.2385
# 188
# Cell is -10000
# Coordinates:  12.1696 , -68.99
# 189
# Cell is -10000
# Coordinates:  18.0425 , -63.0548
# 190
# Cell is -10000
# Coordinates:  52.1326 , 5.2913
# 191
# Cell is -10000
# Coordinates:  -40.9006 , 174.886
# 192
# Cell is -10000
# Coordinates:  12.865416 , -85.207229
# 193
# Cell is -10000
# Coordinates:  17.607789 , 8.081666
# 194
# Cell is -10000
# Coordinates:  9.082 , 8.6753
# 195
# Cell is -10000
# Coordinates:  41.6086 , 21.7453
# 196
# Cell is -10000
# Coordinates:  60.472 , 8.4689
# 197
# Cell is -10000
# Coordinates:  21.512583 , 55.92325500000001
# 198
# Cell is -10000
# Coordinates:  30.3753 , 69.3451
# 199
# Cell is -10000
# Coordinates:  8.538 , -80.7821
# 200
# Cell is -10000
# Coordinates:  -6.314993 , 143.95555
# 201
# Cell is -10000
# Coordinates:  -23.4425 , -58.4438
# 202
# Cell is -10000
# Coordinates:  -9.19 , -75.0152
# 203
# Cell is -10000
# Coordinates:  12.879721 , 121.774017
# 204
# Cell is -10000
# Coordinates:  51.9194 , 19.1451
# 205
# Cell is -10000
# Coordinates:  39.3999 , -8.2245
# 206
# Cell is -10000
# Coordinates:  25.3548 , 51.1839
# 207
# Cell is -10000
# Coordinates:  45.9432 , 24.9668
# 208
# Cell is -10000
# Coordinates:  61.52401 , 105.318756
# 209
# Cell is -10000
# Coordinates:  -1.9403 , 29.8739
# 210
# Cell is -10000
# Coordinates:  17.357822 , -62.782998
# 211
# Cell is -10000
# Coordinates:  13.9094 , -60.9789
# 212
# Cell is -10000
# Coordinates:  12.9843 , -61.2872
# 213
# Cell is -10000
# Coordinates:  43.9424 , 12.4578
# 214
# Cell is -10000
# Coordinates:  0.1864 , 6.6131
# 215
# Cell is -10000
# Coordinates:  23.885942 , 45.079162
# 216
# Cell is -10000
# Coordinates:  14.4974 , -14.4524
# 217
# Cell is -10000
# Coordinates:  44.0165 , 21.0059
# 218
# Cell is -10000
# Coordinates:  -4.6796 , 55.492
# 219
# Cell is -10000
# Coordinates:  8.460555000000001 , -11.779889
# 220
# Cell is -10000
# Coordinates:  1.2833 , 103.8333
# 221
# Cell is -10000
# Coordinates:  48.669 , 19.699
# 222
# Cell is -10000
# Coordinates:  46.1512 , 14.9955
# 223
# Cell is -10000
# Coordinates:  5.152149 , 46.199616
# 224
# Cell is -10000
# Coordinates:  -30.5595 , 22.9375
# 225
# Cell is -10000
# Coordinates:  6.877000000000002 , 31.307
# 226
# Cell is -10000
# Coordinates:  40.463667 , -3.74922
# 227
# Cell is -10000
# Coordinates:  7.873054 , 80.77179699999998
# 228
# Cell is -10000
# Coordinates:  12.8628 , 30.2176
# 229
# Cell is -10000
# Coordinates:  3.9193 , -56.0278
# 230
# Cell is -10000
# Coordinates:  60.128161 , 18.643501
# 231
# Cell is -10000
# Coordinates:  46.8182 , 8.2275
# 232
# Cell is -10000
# Coordinates:  34.802075 , 38.99681500000001
# 233
# Cell is -10000
# Coordinates:  23.7 , 121.0
# 234
# Cell is -10000
# Coordinates:  38.861 , 71.2761
# 235
# Cell is -10000
# Coordinates:  -6.369028 , 34.888822
# 236
# Cell is -10000
# Coordinates:  15.870032 , 100.992541
# 237
# Cell is -10000
# Coordinates:  -8.874217 , 125.727539
# 238
# Cell is -10000
# Coordinates:  8.6195 , 0.8248
# 239
# Cell is -10000
# Coordinates:  10.6918 , -61.2225
# 240
# Cell is -10000
# Coordinates:  33.886917 , 9.537499
# 241
# Cell is -10000
# Coordinates:  38.9637 , 35.2433
# 242
# Cell is -10000
# Coordinates:  40.0 , -100.0
# 243
# Cell is -10000
# Coordinates:  1.373333 , 32.290275
# 244
# Cell is -10000
# Coordinates:  48.3794 , 31.1656
# 245
# Cell is -10000
# Coordinates:  23.424076 , 53.847818
# 246
# Cell is -10000
# Coordinates:  18.2206 , -63.0686
# 247
# Cell is -10000
# Coordinates:  32.3078 , -64.7505
# 248
# Cell is -10000
# Coordinates:  18.4207 , -64.64
# 249
# Cell is -10000
# Coordinates:  19.3133 , -81.2546
# 250
# Cell is -10000
# Coordinates:  49.3723 , -2.3644
# 251
# Cell is -10000
# Coordinates:  -51.7963 , -59.5236
# 252
# Cell is -10000
# Coordinates:  36.1408 , -5.3536
# 253
# Cell is -10000
# Coordinates:  54.2361 , -4.5481
# 254
# Cell is -10000
# Coordinates:  16.742498 , -62.187366
# 255
# Cell is -10000
# Coordinates:  21.69400000000001 , -71.7979
# 256
# Cell is -10000
# Coordinates:  55.3781 , -3.4360000000000004
# 257
# Cell is -10000
# Coordinates:  -32.5228 , -55.7658
# 258
# Cell is -10000
# Coordinates:  41.377491 , 64.585262
# 259
# Cell is -10000
# Coordinates:  6.4238 , -66.5897
# 260
# Cell is -10000
# Coordinates:  14.058324 , 108.277199
# 261
# Cell is -10000
# Coordinates:  31.9522 , 35.2332
# 262
# Cell is -10000
# Coordinates:  24.2155 , -12.8858
# 263
# Cell is -10000
# Coordinates:  15.552727 , 48.516388
# 264
# Cell is -10000
# Coordinates:  -13.133897 , 27.849332
# 265
# Cell is -10000
# Coordinates:  -19.015438 , 29.154857
# 266
# Cell is -10000
# Coordinates:  33.93911 , 67.709953
# 267
# Cell is -10000
# Coordinates:  41.1533 , 20.1683
# 268
# Cell is -10000
# Coordinates:  28.0339 , 1.6596
# 269
# Cell is -10000
# Coordinates:  42.5063 , 1.5218
# 270
# Cell is -10000
# Coordinates:  -11.2027 , 17.8739
# 271
# Cell is -10000
# Coordinates:  17.0608 , -61.7964
# 272
# Cell is -10000
# Coordinates:  -38.4161 , -63.6167
# 273
# Cell is -10000
# Coordinates:  40.0691 , 45.0382
# 274
# Cell is -10000
# Coordinates:  -35.4735 , 149.0124
# 275
# Cell is -10000
# Coordinates:  -33.8688 , 151.2093
# 276
# Cell is -10000
# Coordinates:  -12.4634 , 130.8456
# 277
# Cell is -10000
# Coordinates:  -27.4698 , 153.0251
# 278
# Cell is -10000
# Coordinates:  -34.9285 , 138.6007
# 279
# Cell is -10000
# Coordinates:  -42.8821 , 147.3272
# 280
# Cell is -10000
# Coordinates:  -37.8136 , 144.9631
# 281
# Cell is -10000
# Coordinates:  -31.9505 , 115.8605
# 282
# Cell is -10000
# Coordinates:  47.5162 , 14.5501
# 283
# Cell is -10000
# Coordinates:  40.1431 , 47.5769
# 284
# Cell is -10000
# Coordinates:  25.025885 , -78.035889
# 285
# Cell is -10000
# Coordinates:  26.0275 , 50.55
# 286
# Cell is -10000
# Coordinates:  23.685 , 90.3563
# 287
# Cell is -10000
# Coordinates:  13.1939 , -59.5432
# 288
# Cell is -10000
# Coordinates:  53.7098 , 27.9534
# 289
# Cell is -10000
# Coordinates:  50.8333 , 4.469936
# 290
# Cell is -10000
# Coordinates:  17.1899 , -88.4976
# 291
# Cell is -10000
# Coordinates:  9.3077 , 2.3158
# 292
# Cell is -10000
# Coordinates:  27.5142 , 90.4336
# 293
# Cell is -10000
# Coordinates:  -16.2902 , -63.5887
# 294
# Cell is -10000
# Coordinates:  43.9159 , 17.6791
# 295
# Cell is -10000
# Coordinates:  -22.3285 , 24.6849
# 296
# Cell is -10000
# Coordinates:  -14.235 , -51.9253
# 297
# Cell is -10000
# Coordinates:  4.5353 , 114.7277
# 298
# Cell is -10000
# Coordinates:  42.7339 , 25.4858
# 299
# Cell is -10000
# Coordinates:  12.2383 , -1.5616
# 300
# Cell is -10000
# Coordinates:  21.9162 , 95.956
# 301
# Cell is -10000
# Coordinates:  -3.3731 , 29.9189
# 302
# Cell is -10000
# Coordinates:  16.5388 , -23.0418
# 303
# Cell is -10000
# Coordinates:  11.55 , 104.9167
# 304
# Cell is -10000
# Coordinates:  3.848 , 11.5021
# 305
# Cell is -10000
# Coordinates:  53.9333 , -116.5765
# 306
# Cell is -10000
# Coordinates:  53.7267 , -127.6476
# 307
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 308
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 309
# Cell is -10000
# Coordinates:  53.7609 , -98.8139
# 310
# Cell is -10000
# Coordinates:  46.5653 , -66.4619
# 311
# Cell is -10000
# Coordinates:  53.1355 , -57.6604
# 312
# Cell is -10000
# Coordinates:  64.8255 , -124.8457
# 313
# Cell is -10000
# Coordinates:  44.682 , -63.7443
# 314
# Cell is -10000
# Coordinates:  51.2538 , -85.3232
# 315
# Cell is -10000
# Coordinates:  46.5107 , -63.4168
# 316
# Cell is -10000
# Coordinates:  52.9399 , -73.5491
# 317
# Cell is -10000
# Coordinates:  52.9399 , -106.4509
# 318
# Cell is -10000
# Coordinates:  64.2823 , -135.0
# 319
# Cell is -10000
# Coordinates:  6.6111 , 20.9394
# 320
# Cell is -10000
# Coordinates:  15.4542 , 18.7322
# 321
# Cell is -10000
# Coordinates:  -35.6751 , -71.543
# 322
# Cell is -10000
# Coordinates:  31.8257 , 117.2264
# 323
# Cell is -10000
# Coordinates:  40.1824 , 116.4142
# 324
# Cell is -10000
# Coordinates:  30.0572 , 107.874
# 325
# Cell is -10000
# Coordinates:  26.0789 , 117.9874
# 326
# Cell is -10000
# Coordinates:  35.7518 , 104.2861
# 327
# Cell is -10000
# Coordinates:  23.3417 , 113.4244
# 328
# Cell is -10000
# Coordinates:  23.8298 , 108.7881
# 329
# Cell is -10000
# Coordinates:  26.8154 , 106.8748
# 330
# Cell is -10000
# Coordinates:  19.1959 , 109.7453
# 331
# Cell is -10000
# Coordinates:  39.549 , 116.1306
# 332
# Cell is -10000
# Coordinates:  47.862 , 127.7615
# 333
# Cell is -10000
# Coordinates:  37.8957 , 114.9042
# 334
# Cell is -10000
# Coordinates:  22.3 , 114.2
# 335
# Cell is -10000
# Coordinates:  30.9756 , 112.2707
# 336
# Cell is -10000
# Coordinates:  27.6104 , 111.7088
# 337
# Cell is -10000
# Coordinates:  44.0935 , 113.9448
# 338
# Cell is -10000
# Coordinates:  32.9711 , 119.455
# 339
# Cell is -10000
# Coordinates:  27.614 , 115.7221
# 340
# Cell is -10000
# Coordinates:  43.6661 , 126.1923
# 341
# Cell is -10000
# Coordinates:  41.2956 , 122.6085
# 342
# Cell is -10000
# Coordinates:  22.1667 , 113.55
# 343
# Cell is -10000
# Coordinates:  37.2692 , 106.1655
# 344
# Cell is -10000
# Coordinates:  35.7452 , 95.9956
# 345
# Cell is -10000
# Coordinates:  35.1917 , 108.8701
# 346
# Cell is -10000
# Coordinates:  36.3427 , 118.1498
# 347
# Cell is -10000
# Coordinates:  31.202 , 121.4491
# 348
# Cell is -10000
# Coordinates:  37.5777 , 112.2922
# 349
# Cell is -10000
# Coordinates:  30.6171 , 102.7103
# 350
# Cell is -10000
# Coordinates:  39.3054 , 117.323
# 351
# Cell is -10000
# Coordinates:  31.6927 , 88.0924
# 352
# Cell is -10000
# Coordinates:  41.1129 , 85.2401
# 353
# Cell is -10000
# Coordinates:  24.974 , 101.487
# 354
# Cell is -10000
# Coordinates:  29.1832 , 120.0934
# 355
# Cell is -10000
# Coordinates:  4.5709 , -74.2973
# 356
# Cell is -10000
# Coordinates:  -11.6455 , 43.3333
# 357
# Cell is -10000
# Coordinates:  -0.228 , 15.8277
# 358
# Cell is -10000
# Coordinates:  -4.0383 , 21.7587
# 359
# Cell is -10000
# Coordinates:  9.7489 , -83.7534
# 360
# Cell is -10000
# Coordinates:  7.54 , -5.5471
# 361
# Cell is -10000
# Coordinates:  45.1 , 15.2
# 362
# Cell is -10000
# Coordinates:  21.521757 , -77.78116700000002
# 363
# Cell is -10000
# Coordinates:  35.1264 , 33.4299
# 364
# Cell is -10000
# Coordinates:  49.8175 , 15.473
# 365
# Cell is -10000
# Coordinates:  61.8926 , -6.9118
# 366
# Cell is -10000
# Coordinates:  71.7069 , -42.6043
# Error encountered
# 367
# Cell is -10000
# Coordinates:  56.2639 , 9.5018
# 368
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 369
# Cell is -10000
# Coordinates:  11.8251 , 42.5903
# 370
# Cell is -10000
# Coordinates:  15.415 , -61.371
# 371
# Cell is -10000
# Coordinates:  18.7357 , -70.1627
# 372
# Cell is -10000
# Coordinates:  -1.8312 , -78.1834
# 373
# Cell is -10000
# Coordinates:  26.820553000000004 , 30.802498
# 374
# Cell is -10000
# Coordinates:  13.7942 , -88.8965
# 375
# Cell is -10000
# Coordinates:  1.6508 , 10.2679
# 376
# Cell is -10000
# Coordinates:  15.1794 , 39.7823
# 377
# Cell is -10000
# Coordinates:  58.5953 , 25.0136
# 378
# Cell is -10000
# Coordinates:  -26.5225 , 31.4659
# 379
# Cell is -10000
# Coordinates:  9.145 , 40.4897
# 380
# Cell is -10000
# Coordinates:  -17.7134 , 178.065
# 381
# Cell is -10000
# Coordinates:  61.92411 , 25.748151
# 382
# Cell is -10000
# Coordinates:  3.9339 , -53.1258
# 383
# Cell is -10000
# Coordinates:  -17.6797 , 149.4068
# 384
# Cell is -10000
# Coordinates:  16.265 , -61.551
# 385
# Cell is -10000
# Coordinates:  14.6415 , -61.0242
# 386
# Cell is -10000
# Coordinates:  -12.8275 , 45.166244
# 387
# Cell is -10000
# Coordinates:  -20.904305 , 165.618042
# 388
# Cell is -10000
# Coordinates:  -21.1151 , 55.5364
# 389
# Cell is -10000
# Coordinates:  17.9 , -62.8333
# 390
# Cell is -10000
# Coordinates:  46.8852 , -56.3159
# 391
# Cell is -10000
# Coordinates:  18.0708 , -63.0501
# 392
# Cell is -10000
# Coordinates:  46.2276 , 2.2137
# 393
# Cell is -10000
# Coordinates:  -0.8037 , 11.6094
# 394
# Cell is -10000
# Coordinates:  13.4432 , -15.3101
# 395
# Cell is -10000
# Coordinates:  42.3154 , 43.3569
# 396
# Cell is -10000
# Coordinates:  51.165691 , 10.451526
# 397
# Cell is -10000
# Coordinates:  7.9465 , -1.0232
# 398
# Cell is -10000
# Coordinates:  39.0742 , 21.8243
# 399
# Cell is -10000
# Coordinates:  12.1165 , -61.679
# 400
# Cell is -10000
# Coordinates:  15.7835 , -90.2308
# 401
# Cell is -10000
# Coordinates:  9.9456 , -9.6966
# 402
# Cell is -10000
# Coordinates:  11.8037 , -15.1804
# 403
# Cell is -10000
# Coordinates:  4.860416000000002 , -58.93018000000001
# 404
# Cell is -10000
# Coordinates:  18.9712 , -72.2852
# 405
# Cell is -10000
# Coordinates:  41.9029 , 12.4534
# 406
# Cell is -10000
# Coordinates:  15.2 , -86.2419
# 407
# Cell is -10000
# Coordinates:  47.1625 , 19.5033
# 408
# Cell is -10000
# Coordinates:  64.9631 , -19.0208
# 409
# Cell is -10000
# Coordinates:  20.593684 , 78.96288
# 410
# Cell is -10000
# Coordinates:  -0.7893 , 113.9213
# 411
# Cell is -10000
# Coordinates:  32.427908 , 53.68804599999999
# 412
# Cell is -10000
# Coordinates:  33.223191 , 43.679291
# 413
# Cell is -10000
# Coordinates:  53.1424 , -7.6921
# 414
# Cell is -10000
# Coordinates:  31.046051 , 34.851612
# 415
# Cell is -10000
# Coordinates:  41.87194 , 12.56738
# 416
# Cell is -10000
# Coordinates:  18.1096 , -77.2975
# 417
# Cell is -10000
# Coordinates:  36.204824 , 138.252924
# 418
# Cell is -10000
# Coordinates:  31.24 , 36.51
# 419
# Cell is -10000
# Coordinates:  48.0196 , 66.9237
# 420
# Cell is -10000
# Coordinates:  -0.0236 , 37.9062
# 421
# Cell is -10000
# Coordinates:  35.90775700000001 , 127.766922
# 422
# Cell is -10000
# Coordinates:  42.602636 , 20.902977
# 423
# Cell is -10000
# Coordinates:  29.31166 , 47.481766
# 424
# Cell is -10000
# Coordinates:  41.20438 , 74.766098
# 425
# Cell is -10000
# Coordinates:  19.85627 , 102.495496
# 426
# Cell is -10000
# Coordinates:  56.8796 , 24.6032
# 427
# Cell is -10000
# Coordinates:  33.8547 , 35.8623
# 428
# Cell is -10000
# Coordinates:  -29.61 , 28.2336
# 429
# Cell is -10000
# Coordinates:  6.4280550000000005 , -9.429499
# 430
# Cell is -10000
# Coordinates:  26.3351 , 17.228331
# 431
# Cell is -10000
# Coordinates:  47.14 , 9.55
# 432
# Cell is -10000
# Coordinates:  55.1694 , 23.8813
# 433
# Cell is -10000
# Coordinates:  49.8153 , 6.1296
# 434
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 435
# Cell is -10000
# Coordinates:  -18.766947 , 46.869107
# 436
# Cell is -10000
# Coordinates:  -13.2543 , 34.3015
# 437
# Cell is -10000
# Coordinates:  4.210483999999999 , 101.975766
# 438
# Cell is -10000
# Coordinates:  3.2028 , 73.2207
# 439
# Cell is -10000
# Coordinates:  17.570692 , -3.996166000000001
# 440
# Cell is -10000
# Coordinates:  35.9375 , 14.3754
# 441
# Cell is -10000
# Coordinates:  21.0079 , -10.9408
# 442
# Cell is -10000
# Coordinates:  -20.348404 , 57.552152
# 443
# Cell is -10000
# Coordinates:  23.6345 , -102.5528
# 444
# Cell is -10000
# Coordinates:  47.4116 , 28.3699
# 445
# Cell is -10000
# Coordinates:  43.7333 , 7.4167
# 446
# Cell is -10000
# Coordinates:  46.8625 , 103.8467
# 447
# Cell is -10000
# Coordinates:  42.708678000000006 , 19.37439
# 448
# Cell is -10000
# Coordinates:  31.7917 , -7.0926
# 449
# Cell is -10000
# Coordinates:  -18.665695 , 35.529562
# 450
# Cell is -10000
# Coordinates:  -22.9576 , 18.4904
# 451
# Cell is -10000
# Coordinates:  28.1667 , 84.25
# 452
# Cell is -10000
# Coordinates:  12.5211 , -69.9683
# 453
# Cell is -10000
# Coordinates:  12.1784 , -68.2385
# 454
# Cell is -10000
# Coordinates:  12.1696 , -68.99
# 455
# Cell is -10000
# Coordinates:  18.0425 , -63.0548
# 456
# Cell is -10000
# Coordinates:  52.1326 , 5.2913
# 457
# Cell is -10000
# Coordinates:  -40.9006 , 174.886
# 458
# Cell is -10000
# Coordinates:  12.865416 , -85.207229
# 459
# Cell is -10000
# Coordinates:  17.607789 , 8.081666
# 460
# Cell is -10000
# Coordinates:  9.082 , 8.6753
# 461
# Cell is -10000
# Coordinates:  41.6086 , 21.7453
# 462
# Cell is -10000
# Coordinates:  60.472 , 8.4689
# 463
# Cell is -10000
# Coordinates:  21.512583 , 55.92325500000001
# 464
# Cell is -10000
# Coordinates:  30.3753 , 69.3451
# 465
# Cell is -10000
# Coordinates:  8.538 , -80.7821
# 466
# Cell is -10000
# Coordinates:  -6.314993 , 143.95555
# 467
# Cell is -10000
# Coordinates:  -23.4425 , -58.4438
# 468
# Cell is -10000
# Coordinates:  -9.19 , -75.0152
# 469
# Cell is -10000
# Coordinates:  12.879721 , 121.774017
# 470
# Cell is -10000
# Coordinates:  51.9194 , 19.1451
# 471
# Cell is -10000
# Coordinates:  39.3999 , -8.2245
# 472
# Cell is -10000
# Coordinates:  25.3548 , 51.1839
# 473
# Cell is -10000
# Coordinates:  45.9432 , 24.9668
# 474
# Cell is -10000
# Coordinates:  61.52401 , 105.318756
# 475
# Cell is -10000
# Coordinates:  -1.9403 , 29.8739
# 476
# Cell is -10000
# Coordinates:  17.357822 , -62.782998
# 477
# Cell is -10000
# Coordinates:  13.9094 , -60.9789
# 478
# Cell is -10000
# Coordinates:  12.9843 , -61.2872
# 479
# Cell is -10000
# Coordinates:  43.9424 , 12.4578
# 480
# Cell is -10000
# Coordinates:  0.1864 , 6.6131
# 481
# Cell is -10000
# Coordinates:  23.885942 , 45.079162
# 482
# Cell is -10000
# Coordinates:  14.4974 , -14.4524
# 483
# Cell is -10000
# Coordinates:  44.0165 , 21.0059
# 484
# Cell is -10000
# Coordinates:  -4.6796 , 55.492
# 485
# Cell is -10000
# Coordinates:  8.460555000000001 , -11.779889
# 486
# Cell is -10000
# Coordinates:  1.2833 , 103.8333
# 487
# Cell is -10000
# Coordinates:  48.669 , 19.699
# 488
# Cell is -10000
# Coordinates:  46.1512 , 14.9955
# 489
# Cell is -10000
# Coordinates:  5.152149 , 46.199616
# 490
# Cell is -10000
# Coordinates:  -30.5595 , 22.9375
# 491
# Cell is -10000
# Coordinates:  6.877000000000002 , 31.307
# 492
# Cell is -10000
# Coordinates:  40.463667 , -3.74922
# 493
# Cell is -10000
# Coordinates:  7.873054 , 80.77179699999998
# 494
# Cell is -10000
# Coordinates:  12.8628 , 30.2176
# 495
# Cell is -10000
# Coordinates:  3.9193 , -56.0278
# 496
# Cell is -10000
# Coordinates:  60.128161 , 18.643501
# 497
# Cell is -10000
# Coordinates:  46.8182 , 8.2275
# 498
# Cell is -10000
# Coordinates:  34.802075 , 38.99681500000001
# 499
# Cell is -10000
# Coordinates:  23.7 , 121.0
# 500
# Cell is -10000
# Coordinates:  38.861 , 71.2761
# 501
# Cell is -10000
# Coordinates:  -6.369028 , 34.888822
# 502
# Cell is -10000
# Coordinates:  15.870032 , 100.992541
# 503
# Cell is -10000
# Coordinates:  -8.874217 , 125.727539
# 504
# Cell is -10000
# Coordinates:  8.6195 , 0.8248
# 505
# Cell is -10000
# Coordinates:  10.6918 , -61.2225
# 506
# Cell is -10000
# Coordinates:  33.886917 , 9.537499
# 507
# Cell is -10000
# Coordinates:  38.9637 , 35.2433
# 508
# Cell is -10000
# Coordinates:  40.0 , -100.0
# 509
# Cell is -10000
# Coordinates:  1.373333 , 32.290275
# 510
# Cell is -10000
# Coordinates:  48.3794 , 31.1656
# 511
# Cell is -10000
# Coordinates:  23.424076 , 53.847818
# 512
# Cell is -10000
# Coordinates:  18.2206 , -63.0686
# 513
# Cell is -10000
# Coordinates:  32.3078 , -64.7505
# 514
# Cell is -10000
# Coordinates:  18.4207 , -64.64
# 515
# Cell is -10000
# Coordinates:  19.3133 , -81.2546
# 516
# Cell is -10000
# Coordinates:  49.3723 , -2.3644
# 517
# Cell is -10000
# Coordinates:  -51.7963 , -59.5236
# 518
# Cell is -10000
# Coordinates:  36.1408 , -5.3536
# 519
# Cell is -10000
# Coordinates:  54.2361 , -4.5481
# 520
# Cell is -10000
# Coordinates:  16.742498 , -62.187366
# 521
# Cell is -10000
# Coordinates:  21.69400000000001 , -71.7979
# 522
# Cell is -10000
# Coordinates:  55.3781 , -3.4360000000000004
# 523
# Cell is -10000
# Coordinates:  -32.5228 , -55.7658
# 524
# Cell is -10000
# Coordinates:  41.377491 , 64.585262
# 525
# Cell is -10000
# Coordinates:  6.4238 , -66.5897
# 526
# Cell is -10000
# Coordinates:  14.058324 , 108.277199
# 527
# Cell is -10000
# Coordinates:  31.9522 , 35.2332
# 528
# Cell is -10000
# Coordinates:  24.2155 , -12.8858
# 529
# Cell is -10000
# Coordinates:  15.552727 , 48.516388
# 530
# Cell is -10000
# Coordinates:  -13.133897 , 27.849332
# 531
# Cell is -10000
# Coordinates:  -19.015438 , 29.154857
# 532
# Cell is -10000
# Coordinates:  33.93911 , 67.709953
# 533
# Cell is -10000
# Coordinates:  41.1533 , 20.1683
# 534
# Cell is -10000
# Coordinates:  28.0339 , 1.6596
# 535
# Cell is -10000
# Coordinates:  42.5063 , 1.5218
# 536
# Cell is -10000
# Coordinates:  -11.2027 , 17.8739
# 537
# Cell is -10000
# Coordinates:  17.0608 , -61.7964
# 538
# Cell is -10000
# Coordinates:  -38.4161 , -63.6167
# 539
# Cell is -10000
# Coordinates:  40.0691 , 45.0382
# 540
# Cell is -10000
# Coordinates:  -35.4735 , 149.0124
# 541
# Cell is -10000
# Coordinates:  -33.8688 , 151.2093
# 542
# Cell is -10000
# Coordinates:  -12.4634 , 130.8456
# 543
# Cell is -10000
# Coordinates:  -27.4698 , 153.0251
# 544
# Cell is -10000
# Coordinates:  -34.9285 , 138.6007
# 545
# Cell is -10000
# Coordinates:  -42.8821 , 147.3272
# 546
# Cell is -10000
# Coordinates:  -37.8136 , 144.9631
# 547
# Cell is -10000
# Coordinates:  -31.9505 , 115.8605
# 548
# Cell is -10000
# Coordinates:  47.5162 , 14.5501
# 549
# Cell is -10000
# Coordinates:  40.1431 , 47.5769
# 550
# Cell is -10000
# Coordinates:  25.025885 , -78.035889
# 551
# Cell is -10000
# Coordinates:  26.0275 , 50.55
# 552
# Cell is -10000
# Coordinates:  23.685 , 90.3563
# 553
# Cell is -10000
# Coordinates:  13.1939 , -59.5432
# 554
# Cell is -10000
# Coordinates:  53.7098 , 27.9534
# 555
# Cell is -10000
# Coordinates:  50.8333 , 4.469936
# 556
# Cell is -10000
# Coordinates:  17.1899 , -88.4976
# 557
# Cell is -10000
# Coordinates:  9.3077 , 2.3158
# 558
# Cell is -10000
# Coordinates:  27.5142 , 90.4336
# 559
# Cell is -10000
# Coordinates:  -16.2902 , -63.5887
# 560
# Cell is -10000
# Coordinates:  43.9159 , 17.6791
# 561
# Cell is -10000
# Coordinates:  -22.3285 , 24.6849
# 562
# Cell is -10000
# Coordinates:  -14.235 , -51.9253
# 563
# Cell is -10000
# Coordinates:  4.5353 , 114.7277
# 564
# Cell is -10000
# Coordinates:  42.7339 , 25.4858
# 565
# Cell is -10000
# Coordinates:  12.2383 , -1.5616
# 566
# Cell is -10000
# Coordinates:  21.9162 , 95.956
# 567
# Cell is -10000
# Coordinates:  -3.3731 , 29.9189
# 568
# Cell is -10000
# Coordinates:  16.5388 , -23.0418
# 569
# Cell is -10000
# Coordinates:  11.55 , 104.9167
# 570
# Cell is -10000
# Coordinates:  3.848 , 11.5021
# 571
# Cell is -10000
# Coordinates:  53.9333 , -116.5765
# 572
# Cell is -10000
# Coordinates:  53.7267 , -127.6476
# 573
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 574
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 575
# Cell is -10000
# Coordinates:  53.7609 , -98.8139
# 576
# Cell is -10000
# Coordinates:  46.5653 , -66.4619
# 577
# Cell is -10000
# Coordinates:  53.1355 , -57.6604
# 578
# Cell is -10000
# Coordinates:  64.8255 , -124.8457
# 579
# Cell is -10000
# Coordinates:  44.682 , -63.7443
# 580
# Cell is -10000
# Coordinates:  51.2538 , -85.3232
# 581
# Cell is -10000
# Coordinates:  46.5107 , -63.4168
# 582
# Cell is -10000
# Coordinates:  52.9399 , -73.5491
# 583
# Cell is -10000
# Coordinates:  52.9399 , -106.4509
# 584
# Cell is -10000
# Coordinates:  64.2823 , -135.0
# 585
# Cell is -10000
# Coordinates:  6.6111 , 20.9394
# 586
# Cell is -10000
# Coordinates:  15.4542 , 18.7322
# 587
# Cell is -10000
# Coordinates:  -35.6751 , -71.543
# 588
# Cell is -10000
# Coordinates:  31.8257 , 117.2264
# 589
# Cell is -10000
# Coordinates:  40.1824 , 116.4142
# 590
# Cell is -10000
# Coordinates:  30.0572 , 107.874
# 591
# Cell is -10000
# Coordinates:  26.0789 , 117.9874
# 592
# Cell is -10000
# Coordinates:  35.7518 , 104.2861
# 593
# Cell is -10000
# Coordinates:  23.3417 , 113.4244
# 594
# Cell is -10000
# Coordinates:  23.8298 , 108.7881
# 595
# Cell is -10000
# Coordinates:  26.8154 , 106.8748
# 596
# Cell is -10000
# Coordinates:  19.1959 , 109.7453
# 597
# Cell is -10000
# Coordinates:  39.549 , 116.1306
# 598
# Cell is -10000
# Coordinates:  47.862 , 127.7615
# 599
# Cell is -10000
# Coordinates:  37.8957 , 114.9042
# 600
# Cell is -10000
# Coordinates:  22.3 , 114.2
# 601
# Cell is -10000
# Coordinates:  30.9756 , 112.2707
# 602
# Cell is -10000
# Coordinates:  27.6104 , 111.7088
# 603
# Cell is -10000
# Coordinates:  44.0935 , 113.9448
# 604
# Cell is -10000
# Coordinates:  32.9711 , 119.455
# 605
# Cell is -10000
# Coordinates:  27.614 , 115.7221
# 606
# Cell is -10000
# Coordinates:  43.6661 , 126.1923
# 607
# Cell is -10000
# Coordinates:  41.2956 , 122.6085
# 608
# Cell is -10000
# Coordinates:  22.1667 , 113.55
# 609
# Cell is -10000
# Coordinates:  37.2692 , 106.1655
# 610
# Cell is -10000
# Coordinates:  35.7452 , 95.9956
# 611
# Cell is -10000
# Coordinates:  35.1917 , 108.8701
# 612
# Cell is -10000
# Coordinates:  36.3427 , 118.1498
# 613
# Cell is -10000
# Coordinates:  31.202 , 121.4491
# 614
# Cell is -10000
# Coordinates:  37.5777 , 112.2922
# 615
# Cell is -10000
# Coordinates:  30.6171 , 102.7103
# 616
# Cell is -10000
# Coordinates:  39.3054 , 117.323
# 617
# Cell is -10000
# Coordinates:  31.6927 , 88.0924
# 618
# Cell is -10000
# Coordinates:  41.1129 , 85.2401
# 619
# Cell is -10000
# Coordinates:  24.974 , 101.487
# 620
# Cell is -10000
# Coordinates:  29.1832 , 120.0934
# 621
# Cell is -10000
# Coordinates:  4.5709 , -74.2973
# 622
# Cell is -10000
# Coordinates:  -11.6455 , 43.3333
# 623
# Cell is -10000
# Coordinates:  -0.228 , 15.8277
# 624
# Cell is -10000
# Coordinates:  -4.0383 , 21.7587
# 625
# Cell is -10000
# Coordinates:  9.7489 , -83.7534
# 626
# Cell is -10000
# Coordinates:  7.54 , -5.5471
# 627
# Cell is -10000
# Coordinates:  45.1 , 15.2
# 628
# Cell is -10000
# Coordinates:  21.521757 , -77.78116700000002
# 629
# Cell is -10000
# Coordinates:  35.1264 , 33.4299
# 630
# Cell is -10000
# Coordinates:  49.8175 , 15.473
# 631
# Cell is -10000
# Coordinates:  61.8926 , -6.9118
# 632
# Cell is -10000
# Coordinates:  71.7069 , -42.6043
# Error encountered
# 633
# Cell is -10000
# Coordinates:  56.2639 , 9.5018
# 634
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 635
# Cell is -10000
# Coordinates:  11.8251 , 42.5903
# 636
# Cell is -10000
# Coordinates:  15.415 , -61.371
# 637
# Cell is -10000
# Coordinates:  18.7357 , -70.1627
# 638
# Cell is -10000
# Coordinates:  -1.8312 , -78.1834
# 639
# Cell is -10000
# Coordinates:  26.820553000000004 , 30.802498
# 640
# Cell is -10000
# Coordinates:  13.7942 , -88.8965
# 641
# Cell is -10000
# Coordinates:  1.6508 , 10.2679
# 642
# Cell is -10000
# Coordinates:  15.1794 , 39.7823
# 643
# Cell is -10000
# Coordinates:  58.5953 , 25.0136
# 644
# Cell is -10000
# Coordinates:  -26.5225 , 31.4659
# 645
# Cell is -10000
# Coordinates:  9.145 , 40.4897
# 646
# Cell is -10000
# Coordinates:  -17.7134 , 178.065
# 647
# Cell is -10000
# Coordinates:  61.92411 , 25.748151
# 648
# Cell is -10000
# Coordinates:  3.9339 , -53.1258
# 649
# Cell is -10000
# Coordinates:  -17.6797 , 149.4068
# 650
# Cell is -10000
# Coordinates:  16.265 , -61.551
# 651
# Cell is -10000
# Coordinates:  14.6415 , -61.0242
# 652
# Cell is -10000
# Coordinates:  -12.8275 , 45.166244
# 653
# Cell is -10000
# Coordinates:  -20.904305 , 165.618042
# 654
# Cell is -10000
# Coordinates:  -21.1151 , 55.5364
# 655
# Cell is -10000
# Coordinates:  17.9 , -62.8333
# 656
# Cell is -10000
# Coordinates:  46.8852 , -56.3159
# 657
# Cell is -10000
# Coordinates:  18.0708 , -63.0501
# 658
# Cell is -10000
# Coordinates:  46.2276 , 2.2137
# 659
# Cell is -10000
# Coordinates:  -0.8037 , 11.6094
# 660
# Cell is -10000
# Coordinates:  13.4432 , -15.3101
# 661
# Cell is -10000
# Coordinates:  42.3154 , 43.3569
# 662
# Cell is -10000
# Coordinates:  51.165691 , 10.451526
# 663
# Cell is -10000
# Coordinates:  7.9465 , -1.0232
# 664
# Cell is -10000
# Coordinates:  39.0742 , 21.8243
# 665
# Cell is -10000
# Coordinates:  12.1165 , -61.679
# 666
# Cell is -10000
# Coordinates:  15.7835 , -90.2308
# 667
# Cell is -10000
# Coordinates:  9.9456 , -9.6966
# 668
# Cell is -10000
# Coordinates:  11.8037 , -15.1804
# 669
# Cell is -10000
# Coordinates:  4.860416000000002 , -58.93018000000001
# 670
# Cell is -10000
# Coordinates:  18.9712 , -72.2852
# 671
# Cell is -10000
# Coordinates:  41.9029 , 12.4534
# 672
# Cell is -10000
# Coordinates:  15.2 , -86.2419
# 673
# Cell is -10000
# Coordinates:  47.1625 , 19.5033
# 674
# Cell is -10000
# Coordinates:  64.9631 , -19.0208
# 675
# Cell is -10000
# Coordinates:  20.593684 , 78.96288
# 676
# Cell is -10000
# Coordinates:  -0.7893 , 113.9213
# 677
# Cell is -10000
# Coordinates:  32.427908 , 53.68804599999999
# 678
# Cell is -10000
# Coordinates:  33.223191 , 43.679291
# 679
# Cell is -10000
# Coordinates:  53.1424 , -7.6921
# 680
# Cell is -10000
# Coordinates:  31.046051 , 34.851612
# 681
# Cell is -10000
# Coordinates:  41.87194 , 12.56738
# 682
# Cell is -10000
# Coordinates:  18.1096 , -77.2975
# 683
# Cell is -10000
# Coordinates:  36.204824 , 138.252924
# 684
# Cell is -10000
# Coordinates:  31.24 , 36.51
# 685
# Cell is -10000
# Coordinates:  48.0196 , 66.9237
# 686
# Cell is -10000
# Coordinates:  -0.0236 , 37.9062
# 687
# Cell is -10000
# Coordinates:  35.90775700000001 , 127.766922
# 688
# Cell is -10000
# Coordinates:  42.602636 , 20.902977
# 689
# Cell is -10000
# Coordinates:  29.31166 , 47.481766
# 690
# Cell is -10000
# Coordinates:  41.20438 , 74.766098
# 691
# Cell is -10000
# Coordinates:  19.85627 , 102.495496
# 692
# Cell is -10000
# Coordinates:  56.8796 , 24.6032
# 693
# Cell is -10000
# Coordinates:  33.8547 , 35.8623
# 694
# Cell is -10000
# Coordinates:  -29.61 , 28.2336
# 695
# Cell is -10000
# Coordinates:  6.4280550000000005 , -9.429499
# 696
# Cell is -10000
# Coordinates:  26.3351 , 17.228331
# 697
# Cell is -10000
# Coordinates:  47.14 , 9.55
# 698
# Cell is -10000
# Coordinates:  55.1694 , 23.8813
# 699
# Cell is -10000
# Coordinates:  49.8153 , 6.1296
# 700
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 701
# Cell is -10000
# Coordinates:  -18.766947 , 46.869107
# 702
# Cell is -10000
# Coordinates:  -13.2543 , 34.3015
# 703
# Cell is -10000
# Coordinates:  4.210483999999999 , 101.975766
# 704
# Cell is -10000
# Coordinates:  3.2028 , 73.2207
# 705
# Cell is -10000
# Coordinates:  17.570692 , -3.996166000000001
# 706
# Cell is -10000
# Coordinates:  35.9375 , 14.3754
# 707
# Cell is -10000
# Coordinates:  21.0079 , -10.9408
# 708
# Cell is -10000
# Coordinates:  -20.348404 , 57.552152
# 709
# Cell is -10000
# Coordinates:  23.6345 , -102.5528
# 710
# Cell is -10000
# Coordinates:  47.4116 , 28.3699
# 711
# Cell is -10000
# Coordinates:  43.7333 , 7.4167
# 712
# Cell is -10000
# Coordinates:  46.8625 , 103.8467
# 713
# Cell is -10000
# Coordinates:  42.708678000000006 , 19.37439
# 714
# Cell is -10000
# Coordinates:  31.7917 , -7.0926
# 715
# Cell is -10000
# Coordinates:  -18.665695 , 35.529562
# 716
# Cell is -10000
# Coordinates:  -22.9576 , 18.4904
# 717
# Cell is -10000
# Coordinates:  28.1667 , 84.25
# 718
# Cell is -10000
# Coordinates:  12.5211 , -69.9683
# 719
# Cell is -10000
# Coordinates:  12.1784 , -68.2385
# 720
# Cell is -10000
# Coordinates:  12.1696 , -68.99
# 721
# Cell is -10000
# Coordinates:  18.0425 , -63.0548
# 722
# Cell is -10000
# Coordinates:  52.1326 , 5.2913
# 723
# Cell is -10000
# Coordinates:  -40.9006 , 174.886
# 724
# Cell is -10000
# Coordinates:  12.865416 , -85.207229
# 725
# Cell is -10000
# Coordinates:  17.607789 , 8.081666
# 726
# Cell is -10000
# Coordinates:  9.082 , 8.6753
# 727
# Cell is -10000
# Coordinates:  41.6086 , 21.7453
# 728
# Cell is -10000
# Coordinates:  60.472 , 8.4689
# 729
# Cell is -10000
# Coordinates:  21.512583 , 55.92325500000001
# 730
# Cell is -10000
# Coordinates:  30.3753 , 69.3451
# 731
# Cell is -10000
# Coordinates:  8.538 , -80.7821
# 732
# Cell is -10000
# Coordinates:  -6.314993 , 143.95555
# 733
# Cell is -10000
# Coordinates:  -23.4425 , -58.4438
# 734
# Cell is -10000
# Coordinates:  -9.19 , -75.0152
# 735
# Cell is -10000
# Coordinates:  12.879721 , 121.774017
# 736
# Cell is -10000
# Coordinates:  51.9194 , 19.1451
# 737
# Cell is -10000
# Coordinates:  39.3999 , -8.2245
# 738
# Cell is -10000
# Coordinates:  25.3548 , 51.1839
# 739
# Cell is -10000
# Coordinates:  45.9432 , 24.9668
# 740
# Cell is -10000
# Coordinates:  61.52401 , 105.318756
# 741
# Cell is -10000
# Coordinates:  -1.9403 , 29.8739
# 742
# Cell is -10000
# Coordinates:  17.357822 , -62.782998
# 743
# Cell is -10000
# Coordinates:  13.9094 , -60.9789
# 744
# Cell is -10000
# Coordinates:  12.9843 , -61.2872
# 745
# Cell is -10000
# Coordinates:  43.9424 , 12.4578
# 746
# Cell is -10000
# Coordinates:  0.1864 , 6.6131
# 747
# Cell is -10000
# Coordinates:  23.885942 , 45.079162
# 748
# Cell is -10000
# Coordinates:  14.4974 , -14.4524
# 749
# Cell is -10000
# Coordinates:  44.0165 , 21.0059
# 750
# Cell is -10000
# Coordinates:  -4.6796 , 55.492
# 751
# Cell is -10000
# Coordinates:  8.460555000000001 , -11.779889
# 752
# Cell is -10000
# Coordinates:  1.2833 , 103.8333
# 753
# Cell is -10000
# Coordinates:  48.669 , 19.699
# 754
# Cell is -10000
# Coordinates:  46.1512 , 14.9955
# 755
# Cell is -10000
# Coordinates:  5.152149 , 46.199616
# 756
# Cell is -10000
# Coordinates:  -30.5595 , 22.9375
# 757
# Cell is -10000
# Coordinates:  6.877000000000002 , 31.307
# 758
# Cell is -10000
# Coordinates:  40.463667 , -3.74922
# 759
# Cell is -10000
# Coordinates:  7.873054 , 80.77179699999998
# 760
# Cell is -10000
# Coordinates:  12.8628 , 30.2176
# 761
# Cell is -10000
# Coordinates:  3.9193 , -56.0278
# 762
# Cell is -10000
# Coordinates:  60.128161 , 18.643501
# 763
# Cell is -10000
# Coordinates:  46.8182 , 8.2275
# 764
# Cell is -10000
# Coordinates:  34.802075 , 38.99681500000001
# 765
# Cell is -10000
# Coordinates:  23.7 , 121.0
# 766
# Cell is -10000
# Coordinates:  38.861 , 71.2761
# 767
# Cell is -10000
# Coordinates:  -6.369028 , 34.888822
# 768
# Cell is -10000
# Coordinates:  15.870032 , 100.992541
# 769
# Cell is -10000
# Coordinates:  -8.874217 , 125.727539
# 770
# Cell is -10000
# Coordinates:  8.6195 , 0.8248
# 771
# Cell is -10000
# Coordinates:  10.6918 , -61.2225
# 772
# Cell is -10000
# Coordinates:  33.886917 , 9.537499
# 773
# Cell is -10000
# Coordinates:  38.9637 , 35.2433
# 774
# Cell is -10000
# Coordinates:  40.0 , -100.0
# 775
# Cell is -10000
# Coordinates:  1.373333 , 32.290275
# 776
# Cell is -10000
# Coordinates:  48.3794 , 31.1656
# 777
# Cell is -10000
# Coordinates:  23.424076 , 53.847818
# 778
# Cell is -10000
# Coordinates:  18.2206 , -63.0686
# 779
# Cell is -10000
# Coordinates:  32.3078 , -64.7505
# 780
# Cell is -10000
# Coordinates:  18.4207 , -64.64
# 781
# Cell is -10000
# Coordinates:  19.3133 , -81.2546
# 782
# Cell is -10000
# Coordinates:  49.3723 , -2.3644
# 783
# Cell is -10000
# Coordinates:  -51.7963 , -59.5236
# 784
# Cell is -10000
# Coordinates:  36.1408 , -5.3536
# 785
# Cell is -10000
# Coordinates:  54.2361 , -4.5481
# 786
# Cell is -10000
# Coordinates:  16.742498 , -62.187366
# 787
# Cell is -10000
# Coordinates:  21.69400000000001 , -71.7979
# 788
# Cell is -10000
# Coordinates:  55.3781 , -3.4360000000000004
# 789
# Cell is -10000
# Coordinates:  -32.5228 , -55.7658
# 790
# Cell is -10000
# Coordinates:  41.377491 , 64.585262
# 791
# Cell is -10000
# Coordinates:  6.4238 , -66.5897
# 792
# Cell is -10000
# Coordinates:  14.058324 , 108.277199
# 793
# Cell is -10000
# Coordinates:  31.9522 , 35.2332
# 794
# Cell is -10000
# Coordinates:  24.2155 , -12.8858
# 795
# Cell is -10000
# Coordinates:  15.552727 , 48.516388
# 796
# Cell is -10000
# Coordinates:  -13.133897 , 27.849332
# 797
# Cell is -10000
# Coordinates:  -19.015438 , 29.154857
# 798
# Cell is -10000
# Coordinates:  33.93911 , 67.709953
# 799
# Cell is -10000
# Coordinates:  41.1533 , 20.1683
# 800
# Cell is -10000
# Coordinates:  28.0339 , 1.6596
# 801
# Cell is -10000
# Coordinates:  42.5063 , 1.5218
# 802
# Cell is -10000
# Coordinates:  -11.2027 , 17.8739
# 803
# Cell is -10000
# Coordinates:  17.0608 , -61.7964
# 804
# Cell is -10000
# Coordinates:  -38.4161 , -63.6167
# 805
# Cell is -10000
# Coordinates:  40.0691 , 45.0382
# 806
# Cell is -10000
# Coordinates:  -35.4735 , 149.0124
# 807
# Cell is -10000
# Coordinates:  -33.8688 , 151.2093
# 808
# Cell is -10000
# Coordinates:  -12.4634 , 130.8456
# 809
# Cell is -10000
# Coordinates:  -27.4698 , 153.0251
# 810
# Cell is -10000
# Coordinates:  -34.9285 , 138.6007
# 811
# Cell is -10000
# Coordinates:  -42.8821 , 147.3272
# 812
# Cell is -10000
# Coordinates:  -37.8136 , 144.9631
# 813
# Cell is -10000
# Coordinates:  -31.9505 , 115.8605
# 814
# Cell is -10000
# Coordinates:  47.5162 , 14.5501
# 815
# Cell is -10000
# Coordinates:  40.1431 , 47.5769
# 816
# Cell is -10000
# Coordinates:  25.025885 , -78.035889
# 817
# Cell is -10000
# Coordinates:  26.0275 , 50.55
# 818
# Cell is -10000
# Coordinates:  23.685 , 90.3563
# 819
# Cell is -10000
# Coordinates:  13.1939 , -59.5432
# 820
# Cell is -10000
# Coordinates:  53.7098 , 27.9534
# 821
# Cell is -10000
# Coordinates:  50.8333 , 4.469936
# 822
# Cell is -10000
# Coordinates:  17.1899 , -88.4976
# 823
# Cell is -10000
# Coordinates:  9.3077 , 2.3158
# 824
# Cell is -10000
# Coordinates:  27.5142 , 90.4336
# 825
# Cell is -10000
# Coordinates:  -16.2902 , -63.5887
# 826
# Cell is -10000
# Coordinates:  43.9159 , 17.6791
# 827
# Cell is -10000
# Coordinates:  -22.3285 , 24.6849
# 828
# Cell is -10000
# Coordinates:  -14.235 , -51.9253
# 829
# Cell is -10000
# Coordinates:  4.5353 , 114.7277
# 830
# Cell is -10000
# Coordinates:  42.7339 , 25.4858
# 831
# Cell is -10000
# Coordinates:  12.2383 , -1.5616
# 832
# Cell is -10000
# Coordinates:  21.9162 , 95.956
# 833
# Cell is -10000
# Coordinates:  -3.3731 , 29.9189
# 834
# Cell is -10000
# Coordinates:  16.5388 , -23.0418
# 835
# Cell is -10000
# Coordinates:  11.55 , 104.9167
# 836
# Cell is -10000
# Coordinates:  3.848 , 11.5021
# 837
# Cell is -10000
# Coordinates:  53.9333 , -116.5765
# 838
# Cell is -10000
# Coordinates:  53.7267 , -127.6476
# 839
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 840
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 841
# Cell is -10000
# Coordinates:  53.7609 , -98.8139
# 842
# Cell is -10000
# Coordinates:  46.5653 , -66.4619
# 843
# Cell is -10000
# Coordinates:  53.1355 , -57.6604
# 844
# Cell is -10000
# Coordinates:  64.8255 , -124.8457
# 845
# Cell is -10000
# Coordinates:  44.682 , -63.7443
# 846
# Cell is -10000
# Coordinates:  51.2538 , -85.3232
# 847
# Cell is -10000
# Coordinates:  46.5107 , -63.4168
# 848
# Cell is -10000
# Coordinates:  52.9399 , -73.5491
# 849
# Cell is -10000
# Coordinates:  52.9399 , -106.4509
# 850
# Cell is -10000
# Coordinates:  64.2823 , -135.0
# 851
# Cell is -10000
# Coordinates:  6.6111 , 20.9394
# 852
# Cell is -10000
# Coordinates:  15.4542 , 18.7322
# 853
# Cell is -10000
# Coordinates:  -35.6751 , -71.543
# 854
# Cell is -10000
# Coordinates:  31.8257 , 117.2264
# 855
# Cell is -10000
# Coordinates:  40.1824 , 116.4142
# 856
# Cell is -10000
# Coordinates:  30.0572 , 107.874
# 857
# Cell is -10000
# Coordinates:  26.0789 , 117.9874
# 858
# Cell is -10000
# Coordinates:  35.7518 , 104.2861
# 859
# Cell is -10000
# Coordinates:  23.3417 , 113.4244
# 860
# Cell is -10000
# Coordinates:  23.8298 , 108.7881
# 861
# Cell is -10000
# Coordinates:  26.8154 , 106.8748
# 862
# Cell is -10000
# Coordinates:  19.1959 , 109.7453
# 863
# Cell is -10000
# Coordinates:  39.549 , 116.1306
# 864
# Cell is -10000
# Coordinates:  47.862 , 127.7615
# 865
# Cell is -10000
# Coordinates:  37.8957 , 114.9042
# 866
# Cell is -10000
# Coordinates:  22.3 , 114.2
# 867
# Cell is -10000
# Coordinates:  30.9756 , 112.2707
# 868
# Cell is -10000
# Coordinates:  27.6104 , 111.7088
# 869
# Cell is -10000
# Coordinates:  44.0935 , 113.9448
# 870
# Cell is -10000
# Coordinates:  32.9711 , 119.455
# 871
# Cell is -10000
# Coordinates:  27.614 , 115.7221
# 872
# Cell is -10000
# Coordinates:  43.6661 , 126.1923
# 873
# Cell is -10000
# Coordinates:  41.2956 , 122.6085
# 874
# Cell is -10000
# Coordinates:  22.1667 , 113.55
# 875
# Cell is -10000
# Coordinates:  37.2692 , 106.1655
# 876
# Cell is -10000
# Coordinates:  35.7452 , 95.9956
# 877
# Cell is -10000
# Coordinates:  35.1917 , 108.8701
# 878
# Cell is -10000
# Coordinates:  36.3427 , 118.1498
# 879
# Cell is -10000
# Coordinates:  31.202 , 121.4491
# 880
# Cell is -10000
# Coordinates:  37.5777 , 112.2922
# 881
# Cell is -10000
# Coordinates:  30.6171 , 102.7103
# 882
# Cell is -10000
# Coordinates:  39.3054 , 117.323
# 883
# Cell is -10000
# Coordinates:  31.6927 , 88.0924
# 884
# Cell is -10000
# Coordinates:  41.1129 , 85.2401
# 885
# Cell is -10000
# Coordinates:  24.974 , 101.487
# 886
# Cell is -10000
# Coordinates:  29.1832 , 120.0934
# 887
# Cell is -10000
# Coordinates:  4.5709 , -74.2973
# 888
# Cell is -10000
# Coordinates:  -11.6455 , 43.3333
# 889
# Cell is -10000
# Coordinates:  -0.228 , 15.8277
# 890
# Cell is -10000
# Coordinates:  -4.0383 , 21.7587
# 891
# Cell is -10000
# Coordinates:  9.7489 , -83.7534
# 892
# Cell is -10000
# Coordinates:  7.54 , -5.5471
# 893
# Cell is -10000
# Coordinates:  45.1 , 15.2
# 894
# Cell is -10000
# Coordinates:  21.521757 , -77.78116700000002
# 895
# Cell is -10000
# Coordinates:  35.1264 , 33.4299
# 896
# Cell is -10000
# Coordinates:  49.8175 , 15.473
# 897
# Cell is -10000
# Coordinates:  61.8926 , -6.9118
# 898
# Cell is -10000
# Coordinates:  71.7069 , -42.6043
# Error encountered
# 899
# Cell is -10000
# Coordinates:  56.2639 , 9.5018
# 900
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 901
# Cell is -10000
# Coordinates:  11.8251 , 42.5903
# 902
# Cell is -10000
# Coordinates:  15.415 , -61.371
# 903
# Cell is -10000
# Coordinates:  18.7357 , -70.1627
# 904
# Cell is -10000
# Coordinates:  -1.8312 , -78.1834
# 905
# Cell is -10000
# Coordinates:  26.820553000000004 , 30.802498
# 906
# Cell is -10000
# Coordinates:  13.7942 , -88.8965
# 907
# Cell is -10000
# Coordinates:  1.6508 , 10.2679
# 908
# Cell is -10000
# Coordinates:  15.1794 , 39.7823
# 909
# Cell is -10000
# Coordinates:  58.5953 , 25.0136
# 910
# Cell is -10000
# Coordinates:  -26.5225 , 31.4659
# 911
# Cell is -10000
# Coordinates:  9.145 , 40.4897
# 912
# Cell is -10000
# Coordinates:  -17.7134 , 178.065
# 913
# Cell is -10000
# Coordinates:  61.92411 , 25.748151
# 914
# Cell is -10000
# Coordinates:  3.9339 , -53.1258
# 915
# Cell is -10000
# Coordinates:  -17.6797 , 149.4068
# 916
# Cell is -10000
# Coordinates:  16.265 , -61.551
# 917
# Cell is -10000
# Coordinates:  14.6415 , -61.0242
# 918
# Cell is -10000
# Coordinates:  -12.8275 , 45.166244
# 919
# Cell is -10000
# ...
# 2043
# Cell is -10000
# Coordinates:  42.708678000000006 , 19.37439
# 2044
# Cell is -10000
# Coordinates:  31.7917 , -7.0926
# 2045
# Cell is -10000
# Coordinates:  -18.665695 , 35.529562
# 2046
# Cell is -10000
# Coordinates:  -22.9576 , 18.4904
# 2047
# Cell is -10000
# Coordinates:  28.1667 , 84.25
# 2048
# Cell is -10000
# Coordinates:  12.5211 , -69.9683
# 2049
# Cell is -10000
# Coordinates:  12.1784 , -68.2385
# 2050
# Cell is -10000
# Coordinates:  12.1696 , -68.99
# 2051
# Cell is -10000
# Coordinates:  18.0425 , -63.0548
# 2052
# Cell is -10000
# Coordinates:  52.1326 , 5.2913
# 2053
# Cell is -10000
# Coordinates:  -40.9006 , 174.886
# 2054
# Cell is -10000
# Coordinates:  12.865416 , -85.207229
# 2055
# Cell is -10000
# Coordinates:  17.607789 , 8.081666
# 2056
# Cell is -10000
# Coordinates:  9.082 , 8.6753
# 2057
# Cell is -10000
# Coordinates:  41.6086 , 21.7453
# 2058
# Cell is -10000
# Coordinates:  60.472 , 8.4689
# 2059
# Cell is -10000
# Coordinates:  21.512583 , 55.92325500000001
# 2060
# Cell is -10000
# Coordinates:  30.3753 , 69.3451
# 2061
# Cell is -10000
# Coordinates:  8.538 , -80.7821
# 2062
# Cell is -10000
# Coordinates:  -6.314993 , 143.95555
# 2063
# Cell is -10000
# Coordinates:  -23.4425 , -58.4438
# 2064
# Cell is -10000
# Coordinates:  -9.19 , -75.0152
# 2065
# Cell is -10000
# Coordinates:  12.879721 , 121.774017
# 2066
# Cell is -10000
# Coordinates:  51.9194 , 19.1451
# 2067
# Cell is -10000
# Coordinates:  39.3999 , -8.2245
# 2068
# Cell is -10000
# Coordinates:  25.3548 , 51.1839
# 2069
# Cell is -10000
# Coordinates:  45.9432 , 24.9668
# 2070
# Cell is -10000
# Coordinates:  61.52401 , 105.318756
# 2071
# Cell is -10000
# Coordinates:  -1.9403 , 29.8739
# 2072
# Cell is -10000
# Coordinates:  17.357822 , -62.782998
# 2073
# Cell is -10000
# Coordinates:  13.9094 , -60.9789
# 2074
# Cell is -10000
# Coordinates:  12.9843 , -61.2872
# 2075
# Cell is -10000
# Coordinates:  43.9424 , 12.4578
# 2076
# Cell is -10000
# Coordinates:  0.1864 , 6.6131
# 2077
# Cell is -10000
# Coordinates:  23.885942 , 45.079162
# 2078
# Cell is -10000
# Coordinates:  14.4974 , -14.4524
# 2079
# Cell is -10000
# Coordinates:  44.0165 , 21.0059
# 2080
# Cell is -10000
# Coordinates:  -4.6796 , 55.492
# 2081
# Cell is -10000
# Coordinates:  8.460555000000001 , -11.779889
# 2082
# Cell is -10000
# Coordinates:  1.2833 , 103.8333
# 2083
# Cell is -10000
# Coordinates:  48.669 , 19.699
# 2084
# Cell is -10000
# Coordinates:  46.1512 , 14.9955
# 2085
# Cell is -10000
# Coordinates:  5.152149 , 46.199616
# 2086
# Cell is -10000
# Coordinates:  -30.5595 , 22.9375
# 2087
# Cell is -10000
# Coordinates:  6.877000000000002 , 31.307
# 2088
# Cell is -10000
# Coordinates:  40.463667 , -3.74922
# 2089
# Cell is -10000
# Coordinates:  7.873054 , 80.77179699999998
# 2090
# Cell is -10000
# Coordinates:  12.8628 , 30.2176
# 2091
# Cell is -10000
# Coordinates:  3.9193 , -56.0278
# 2092
# Cell is -10000
# Coordinates:  60.128161 , 18.643501
# 2093
# Cell is -10000
# Coordinates:  46.8182 , 8.2275
# 2094
# Cell is -10000
# Coordinates:  34.802075 , 38.99681500000001
# 2095
# Cell is -10000
# Coordinates:  23.7 , 121.0
# 2096
# Cell is -10000
# Coordinates:  38.861 , 71.2761
# 2097
# Cell is -10000
# Coordinates:  -6.369028 , 34.888822
# 2098
# Cell is -10000
# Coordinates:  15.870032 , 100.992541
# 2099
# Cell is -10000
# Coordinates:  -8.874217 , 125.727539
# 2100
# Cell is -10000
# Coordinates:  8.6195 , 0.8248
# 2101
# Cell is -10000
# Coordinates:  10.6918 , -61.2225
# 2102
# Cell is -10000
# Coordinates:  33.886917 , 9.537499
# 2103
# Cell is -10000
# Coordinates:  38.9637 , 35.2433
# 2104
# Cell is -10000
# Coordinates:  40.0 , -100.0
# 2105
# Cell is -10000
# Coordinates:  1.373333 , 32.290275
# 2106
# Cell is -10000
# Coordinates:  48.3794 , 31.1656
# 2107
# Cell is -10000
# Coordinates:  23.424076 , 53.847818
# 2108
# Cell is -10000
# Coordinates:  18.2206 , -63.0686
# 2109
# Cell is -10000
# Coordinates:  32.3078 , -64.7505
# 2110
# Cell is -10000
# Coordinates:  18.4207 , -64.64
# 2111
# Cell is -10000
# Coordinates:  19.3133 , -81.2546
# 2112
# Cell is -10000
# Coordinates:  49.3723 , -2.3644
# 2113
# Cell is -10000
# Coordinates:  -51.7963 , -59.5236
# 2114
# Cell is -10000
# Coordinates:  36.1408 , -5.3536
# 2115
# Cell is -10000
# Coordinates:  54.2361 , -4.5481
# 2116
# Cell is -10000
# Coordinates:  16.742498 , -62.187366
# 2117
# Cell is -10000
# Coordinates:  21.69400000000001 , -71.7979
# 2118
# Cell is -10000
# Coordinates:  55.3781 , -3.4360000000000004
# 2119
# Cell is -10000
# Coordinates:  -32.5228 , -55.7658
# 2120
# Cell is -10000
# Coordinates:  41.377491 , 64.585262
# 2121
# Cell is -10000
# Coordinates:  6.4238 , -66.5897
# 2122
# Cell is -10000
# Coordinates:  14.058324 , 108.277199
# 2123
# Cell is -10000
# Coordinates:  31.9522 , 35.2332
# 2124
# Cell is -10000
# Coordinates:  24.2155 , -12.8858
# 2125
# Cell is -10000
# Coordinates:  15.552727 , 48.516388
# 2126
# Cell is -10000
# Coordinates:  -13.133897 , 27.849332
# 2127
# Cell is -10000
# Coordinates:  -19.015438 , 29.154857
# 2128
# Cell is -10000
# Coordinates:  33.93911 , 67.709953
# 2129
# Cell is -10000
# Coordinates:  41.1533 , 20.1683
# 2130
# Cell is -10000
# Coordinates:  28.0339 , 1.6596
# 2131
# Cell is -10000
# Coordinates:  42.5063 , 1.5218
# 2132
# Cell is -10000
# Coordinates:  -11.2027 , 17.8739
# 2133
# Cell is -10000
# Coordinates:  17.0608 , -61.7964
# 2134
# Cell is -10000
# Coordinates:  -38.4161 , -63.6167
# 2135
# Cell is -10000
# Coordinates:  40.0691 , 45.0382
# 2136
# Cell is -10000
# Coordinates:  -35.4735 , 149.0124
# 2137
# Cell is -10000
# Coordinates:  -33.8688 , 151.2093
# 2138
# Cell is -10000
# Coordinates:  -12.4634 , 130.8456
# 2139
# Cell is -10000
# Coordinates:  -27.4698 , 153.0251
# 2140
# Cell is -10000
# Coordinates:  -34.9285 , 138.6007
# 2141
# Cell is -10000
# Coordinates:  -42.8821 , 147.3272
# 2142
# Cell is -10000
# Coordinates:  -37.8136 , 144.9631
# 2143
# Cell is -10000
# Coordinates:  -31.9505 , 115.8605
# 2144
# Cell is -10000
# Coordinates:  47.5162 , 14.5501
# 2145
# Cell is -10000
# Coordinates:  40.1431 , 47.5769
# 2146
# Cell is -10000
# Coordinates:  25.025885 , -78.035889
# 2147
# Cell is -10000
# Coordinates:  26.0275 , 50.55
# 2148
# Cell is -10000
# Coordinates:  23.685 , 90.3563
# 2149
# Cell is -10000
# Coordinates:  13.1939 , -59.5432
# 2150
# Cell is -10000
# Coordinates:  53.7098 , 27.9534
# 2151
# Cell is -10000
# Coordinates:  50.8333 , 4.469936
# 2152
# Cell is -10000
# Coordinates:  17.1899 , -88.4976
# 2153
# Cell is -10000
# Coordinates:  9.3077 , 2.3158
# 2154
# Cell is -10000
# Coordinates:  27.5142 , 90.4336
# 2155
# Cell is -10000
# Coordinates:  -16.2902 , -63.5887
# 2156
# Cell is -10000
# Coordinates:  43.9159 , 17.6791
# 2157
# Cell is -10000
# Coordinates:  -22.3285 , 24.6849
# 2158
# Cell is -10000
# Coordinates:  -14.235 , -51.9253
# 2159
# Cell is -10000
# Coordinates:  4.5353 , 114.7277
# 2160
# Cell is -10000
# Coordinates:  42.7339 , 25.4858
# 2161
# Cell is -10000
# Coordinates:  12.2383 , -1.5616
# 2162
# Cell is -10000
# Coordinates:  21.9162 , 95.956
# 2163
# Cell is -10000
# Coordinates:  -3.3731 , 29.9189
# 2164
# Cell is -10000
# Coordinates:  16.5388 , -23.0418
# 2165
# Cell is -10000
# Coordinates:  11.55 , 104.9167
# 2166
# Cell is -10000
# Coordinates:  3.848 , 11.5021
# 2167
# Cell is -10000
# Coordinates:  53.9333 , -116.5765
# 2168
# Cell is -10000
# Coordinates:  53.7267 , -127.6476
# 2169
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 2170
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 2171
# Cell is -10000
# Coordinates:  53.7609 , -98.8139
# 2172
# Cell is -10000
# Coordinates:  46.5653 , -66.4619
# 2173
# Cell is -10000
# Coordinates:  53.1355 , -57.6604
# 2174
# Cell is -10000
# Coordinates:  64.8255 , -124.8457
# 2175
# Cell is -10000
# Coordinates:  44.682 , -63.7443
# 2176
# Cell is -10000
# Coordinates:  51.2538 , -85.3232
# 2177
# Cell is -10000
# Coordinates:  46.5107 , -63.4168
# 2178
# Cell is -10000
# Coordinates:  52.9399 , -73.5491
# 2179
# Cell is -10000
# Coordinates:  52.9399 , -106.4509
# 2180
# Cell is -10000
# Coordinates:  64.2823 , -135.0
# 2181
# Cell is -10000
# Coordinates:  6.6111 , 20.9394
# 2182
# Cell is -10000
# Coordinates:  15.4542 , 18.7322
# 2183
# Cell is -10000
# Coordinates:  -35.6751 , -71.543
# 2184
# Cell is -10000
# Coordinates:  31.8257 , 117.2264
# 2185
# Cell is -10000
# Coordinates:  40.1824 , 116.4142
# 2186
# Cell is -10000
# Coordinates:  30.0572 , 107.874
# 2187
# Cell is -10000
# Coordinates:  26.0789 , 117.9874
# 2188
# Cell is -10000
# Coordinates:  35.7518 , 104.2861
# 2189
# Cell is -10000
# Coordinates:  23.3417 , 113.4244
# 2190
# Cell is -10000
# Coordinates:  23.8298 , 108.7881
# 2191
# Cell is -10000
# Coordinates:  26.8154 , 106.8748
# 2192
# Cell is -10000
# Coordinates:  19.1959 , 109.7453
# 2193
# Cell is -10000
# Coordinates:  39.549 , 116.1306
# 2194
# Cell is -10000
# Coordinates:  47.862 , 127.7615
# 2195
# Cell is -10000
# Coordinates:  37.8957 , 114.9042
# 2196
# Cell is -10000
# Coordinates:  22.3 , 114.2
# 2197
# Cell is -10000
# Coordinates:  30.9756 , 112.2707
# 2198
# Cell is -10000
# Coordinates:  27.6104 , 111.7088
# 2199
# Cell is -10000
# Coordinates:  44.0935 , 113.9448
# 2200
# Cell is -10000
# Coordinates:  32.9711 , 119.455
# 2201
# Cell is -10000
# Coordinates:  27.614 , 115.7221
# 2202
# Cell is -10000
# Coordinates:  43.6661 , 126.1923
# 2203
# Cell is -10000
# Coordinates:  41.2956 , 122.6085
# 2204
# Cell is -10000
# Coordinates:  22.1667 , 113.55
# 2205
# Cell is -10000
# Coordinates:  37.2692 , 106.1655
# 2206
# Cell is -10000
# Coordinates:  35.7452 , 95.9956
# 2207
# Cell is -10000
# Coordinates:  35.1917 , 108.8701
# 2208
# Cell is -10000
# Coordinates:  36.3427 , 118.1498
# 2209
# Cell is -10000
# Coordinates:  31.202 , 121.4491
# 2210
# Cell is -10000
# Coordinates:  37.5777 , 112.2922
# 2211
# Cell is -10000
# Coordinates:  30.6171 , 102.7103
# 2212
# Cell is -10000
# Coordinates:  39.3054 , 117.323
# 2213
# Cell is -10000
# Coordinates:  31.6927 , 88.0924
# 2214
# Cell is -10000
# Coordinates:  41.1129 , 85.2401
# 2215
# Cell is -10000
# Coordinates:  24.974 , 101.487
# 2216
# Cell is -10000
# Coordinates:  29.1832 , 120.0934
# 2217
# Cell is -10000
# Coordinates:  4.5709 , -74.2973
# 2218
# Cell is -10000
# Coordinates:  -11.6455 , 43.3333
# 2219
# Cell is -10000
# Coordinates:  -0.228 , 15.8277
# 2220
# Cell is -10000
# Coordinates:  -4.0383 , 21.7587
# 2221
# Cell is -10000
# Coordinates:  9.7489 , -83.7534
# 2222
# Cell is -10000
# Coordinates:  7.54 , -5.5471
# 2223
# Cell is -10000
# Coordinates:  45.1 , 15.2
# 2224
# Cell is -10000
# Coordinates:  21.521757 , -77.78116700000002
# 2225
# Cell is -10000
# Coordinates:  35.1264 , 33.4299
# 2226
# Cell is -10000
# Coordinates:  49.8175 , 15.473
# 2227
# Cell is -10000
# Coordinates:  61.8926 , -6.9118
# 2228
# Cell is -10000
# Coordinates:  71.7069 , -42.6043
# Error encountered
# 2229
# Cell is -10000
# Coordinates:  56.2639 , 9.5018
# 2230
# Cell is -10000
# Coordinates:  0.0 , 0.0
# 2231
# Cell is -10000
# Coordinates:  11.8251 , 42.5903
# 2232
# Cell is -10000
# Coordinates:  15.415 , -61.371
# 2233
# Cell is -10000
# Coordinates:  18.7357 , -70.1627
# 2234
# Cell is -10000
# Coordinates:  -1.8312 , -78.1834
# 2235
# Cell is -10000
# Coordinates:  26.820553000000004 , 30.802498
# 2236
# Cell is -10000
# Coordinates:  13.7942 , -88.8965
# 2237
# Cell is -10000
# Coordinates:  1.6508 , 10.2679
# 2238
# Cell is -10000
# Coordinates:  15.1794 , 39.7823
# 2239
# Cell is -10000
# Coordinates:  58.5953 , 25.0136
# 2240
# Cell is -10000
# Coordinates:  -26.5225 , 31.4659
# 2241
# Cell is -10000
# Coordinates:  9.145 , 40.4897
# 2242
# Cell is -10000
# Coordinates:  -17.7134 , 178.065
# 2243
# Cell is -10000
# Coordinates:  61.92411 , 25.748151
# 2244
# Cell is -10000
# Coordinates:  3.9339 , -53.1258
# 2245
# Cell is -10000
# Coordinates:  -17.6797 , 149.4068
# 2246
# Cell is -10000
# Coordinates:  16.265 , -61.551
# 2247
# Cell is -10000
# Coordinates:  14.6415 , -61.0242
# 2248
# Cell is -10000
# Coordinates:  -12.8275 , 45.166244
# 2249
# Cell is -10000
# Coordinates:  -20.904305 , 165.618042
# 2250
# Cell is -10000
# Coordinates:  -21.1151 , 55.5364
# 2251
# Cell is -10000
# Coordinates:  17.9 , -62.8333
# 2252
# Cell is -10000
# Coordinates:  46.8852 , -56.3159
# 2253
# Cell is -10000
# Coordinates:  18.0708 , -63.0501
# 2254
# Cell is -10000
# Coordinates:  46.2276 , 2.2137
# 2255
# Cell is -10000
# Coordinates:  -0.8037 , 11.6094
# 2256
# Cell is -10000
# Coordinates:  13.4432 , -15.3101
# 2257
# Cell is -10000
# Coordinates:  42.3154 , 43.3569
# 2258
# Cell is -10000
# Coordinates:  51.165691 , 10.451526
# 2259
# Cell is -10000
# Coordinates:  7.9465 , -1.0232
# 2260
# Cell is -10000
# Coordinates:  39.0742 , 21.8243
# 2261
# Cell is -10000
# Coordinates:  12.1165 , -61.679
# 2262
# Cell is -10000
# Coordinates:  15.7835 , -90.2308
# 2263
# Cell is -10000
# Coordinates:  9.9456 , -9.6966
# 2264
# Cell is -10000
# Coordinates:  11.8037 , -15.1804
# 2265
# Cell is -10000
# Coordinates:  4.860416000000002 , -58.93018000000001
# 2266
# Cell is -10000
# Coordinates:  18.9712 , -72.2852
# 2267
# Cell is -10000
# Coordinates:  41.9029 , 12.4534
# 2268
# Cell is -10000
# Coordinates:  15.2 , -86.2419
# 2269
# Cell is -10000
# Coordinates:  47.1625 , 19.5033
# 2270
# Cell is -10000
# Coordinates:  64.9631 , -19.0208
# 2271
# Cell is -10000
# Coordinates:  20.593684 , 78.96288
# 2272
# Cell is -10000
# Coordinates:  -0.7893 , 113.9213
# 2273
# Cell is -10000
# Coordinates:  32.427908 , 53.68804599999999
# 2274
# Cell is -10000
# Coordinates:  33.223191 , 43.679291
# 2275
# Cell is -10000
# Coordinates:  53.1424 , -7.6921
# 2276
# Cell is -10000
# Coordinates:  31.046051 , 34.851612
# 2277
# Cell is -10000
# Coordinates:  41.87194 , 12.56738
# 2278
# Cell is -10000
# Coordinates:  18.1096 , -77.2975
# 2279
# Cell is -10000
# Coordinates:  36.204824 , 138.252924
# 2280
# Cell is -10000
# Coordinates:  31.24 , 36.51
# 2281
# Cell is -10000
# Coordinates:  48.0196 , 66.9237
# 2282
# Cell is -10000
# Coordinates:  -0.0236 , 37.9062
# 2283
# Cell is -10000
# Coordinates:  35.90775700000001 , 127.766922
# 2284
# Cell is -10000
# Coordinates:  42.602636 , 20.902977
# 2285
# Cell is -10000
# Coordinates:  29.31166 , 47.481766
# 2286
# Cell is -10000
# Coordinates:  41.20438 , 74.766098
# 2287
# Cell is -10000
# Coordinates:  19.85627 , 102.495496
# 2288
# Cell is -10000
# Coordinates:  56.8796 , 24.6032
# 2289
# Cell is -10000
# Coordinates:  33.8547 , 35.8623
# 2290
# Cell is -10000
# Coordinates:  -29.61 , 28.2336
# 2291
# Cell is -10000
# Coordinates:  6.4280550000000005 , -9.429499
# 2292
# Cell is -10000
# Coordinates:  26.3351 , 17.228331
# 2293
# Cell is -10000
# Coordinates:  47.14 , 9.55
# 2294
# Cell is -10000
# Coordinates:  55.1694 , 23.8813
# 2295
# Cell is -10000
# Coordinates:  49.8153 , 6.1296
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c0f9f6d14b1d> in <module>
#      66                 # Getting the API call
#      67                 # using the retry error handling established above
# ---> 68                 response = http.get(url)
#      69
#      70                 # Putting the API response into the JSON thing
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     414             raise InvalidURL(e, request=request)
#     415
# --> 416         self.cert_verify(conn, request.url, verify, cert)
#     417         url = self.request_url(request, proxies)
#     418         self.add_headers(request, stream=stream, timeout=timeout, verify=verify, cert=cert, proxies=proxies)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in cert_verify(self, conn, url, verify, cert)
#     224                 cert_loc = extract_zipped_paths(DEFAULT_CA_BUNDLE_PATH)
#     225
# --> 226             if not cert_loc or not os.path.exists(cert_loc):
#     227                 raise IOError("Could not find a suitable TLS CA certificate bundle, "
#     228                               "invalid path: {}".format(cert_loc))
#
# ~/anaconda3/lib/python3.8/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:

# %%
# Writing final data to csv
print('Final data write')
df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
df_sunset.to_csv('./csv/sunset_Global.csv', index=False)

# %%
df_tMax.head(12)

# %%
df_sunset.tail(12)

# %%
df_sunrise.head()

# %%
df_tMax.head(12)

# %%
df_tMin.head(12)

# %%
df_humidity.head(12)

# %%
df_uvIndex.head(12)

# %%
df_cloud.head(12)

# %%
df_precipprob.head(12)

# %%
df_dewpoint.head(12)

# %%
df_pressure.head(12)

# %%
df_windspeed.head(12)

# %%
df_sunrise.head(12)

# %%
# The below modules are for testing things out

# %%
#Darksky API key
API_KEY = '723a6f9dbda64ae1e0b9fdde14ba752e'

#number of seconds in one day
one_day = 86400

t = '1577836800'

latitude = '15'
longitude = '101'

# sample get request 
#GET https://api.darksky.net/forecast/0123456789abcdef9876543210fedcba/
#42.3601,-71.0589,255657600?exclude=currently,flags

url = 'https://api.darksky.net/forecast/' + API_KEY + '/' + latitude + "," + longitude + ',' + t

url = url + '?exclude=currently,flags&units=si'
url

# %%
response = requests.get(url)

# %%
response.content

# %%
info = json.loads(response.content)

info['daily']['data'][0]

# %%
# Test cell
# Resuming the API calls

# Code to increase number of retries on connection errors,
# and also to give it some time.
# Found on https://stackoverflow.com/questions/15431044/can-i-set-max-retries-for-requests-request
# And https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

s = requests.Session()

retries = Retry(total=30,
                backoff_factor=0.1,
                status_forcelist=[ 429, 500, 502, 503, 504 ],
                method_whitelist=["HEAD", "GET", "OPTIONS"])

adapter = HTTPAdapter(max_retries=retries)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)

# pull data from darksky weather API

# Columns to be skipped when iterating through the DataFrame
do_not_include = ['Province/State', 'Country/Region', 'Lat', 'Long']

# Darksky API key
# API_KEY = '8c5957c420f104bbb8f6901ff15f56d0'

# counter
counter = 0

# Dummy value in case of errors
dummy = -1000

# variable for determining how many API calls between writing data to CSV
write_var = 1000

# Start iterating through the date columns
for x in df_tMax.columns.values:
    
    # Skip the columns that are not dates
    if (x not in do_not_include):
        
        # Create Unix time stamp out of the date column
        t = pd.to_datetime(df_tMax[x].name)
        t = int(t.value / 10**9)
        # t = str(t)
                
        # Start iterating through the rows (locations)
        for y in range(df_tMax['1/22/20'].values.size):
            
            # Only do API call if the cell value is 0
            if str(df_tMax.iloc[y][x]) == '-10000':
                
                print('Cell is -10000')
                
                other_dummy = t + y
                
                tMax = other_dummy
                tMin = other_dummy
                hum = other_dummy
                uvee = other_dummy
                clouds = other_dummy
                precip = other_dummy
                dew = other_dummy
                pressure = other_dummy
                wind = other_dummy
                ozone = other_dummy
                sunrise = other_dummy
                sunset = other_dummy

                # Recording the data into the respective dataframes
                df_tMax.at[y, x] = tMax
                df_tMin.at[y, x] = tMin
                df_humidity.at[y, x] = hum
                df_uvIndex.at[y, x] = uvee
                df_cloud.at[y, x] = clouds
                df_precipprob.at[y, x] = precip
                df_dewpoint.at[y, x] = dew
                df_pressure.at[y, x] = pressure
                df_windspeed.at[y, x] = wind
                df_ozone.at[y, x] = ozone
                df_sunrise.at[y,x] = sunrise
                df_sunset.at[y,x] = sunset
            
            counter = counter + 1
            print(counter)

            # writing CSVs of what I've got so far, for every write_var API calls
            if counter % write_var == 0:
                
                print('1000 API calls')
                df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
                df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
                df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
                df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
                df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
                df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
                df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
                df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
                df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
                df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
                df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
                df_sunset.to_csv('./csv/sunset_Global.csv', index=False)

# Writing final data to csv
print('Final data write')
df_tMax.to_csv('./csv/tMax_Global.csv', index=False)
df_tMin.to_csv('./csv/tMin_Global.csv', index=False)
df_humidity.to_csv('./csv/humidity_Global.csv', index=False)
df_uvIndex.to_csv('./csv/uv_Global.csv', index=False)
df_cloud.to_csv('./csv/cloud_Global.csv', index=False)
df_precipprob.to_csv('./csv/precip_Global.csv', index=False)
df_dewpoint.to_csv('./csv/dew_Global.csv', index=False)
df_pressure.to_csv('./csv/pressure_Global.csv', index=False)
df_windspeed.to_csv('./csv/wind_Global.csv', index=False)
df_ozone.to_csv('./csv/ozone_Global.csv', index=False)
df_sunrise.to_csv('./csv/sunrise_Global.csv', index=False)
df_sunset.to_csv('./csv/sunset_Global.csv', index=False)
