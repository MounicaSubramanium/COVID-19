# %% [markdown]
# Using SQL to update weather data

# %%
# sqlite3 library to run operations on the database
import sqlite3

gen_path = '/home/imants/gits/COVID-19/'

db_path = gen_path + 'sql/weather.db'

# connecting to the weather database
con = sqlite3.connect(db_path)

# establishing database cursor
cursorObj = con.cursor()

# %%
# Getting table names

table_names = cursorObj.execute("SELECT name FROM sqlite_master WHERE type='table';")

table_names = table_names.fetchall()

# Taking the table names that were fetched, and making a usable lists out of the values.

US_names = []
global_names = []

for x in range(len(table_names)):
    if (table_names[x][0][-2:] == 'US'):
        US_names.append(table_names[x][0])
        
    else:
        global_names.append(table_names[x][0])
        
 
print('US names', US_names)

print('Global names', global_names)
# Out:
# US names ['cloud_US', 'dew_US', 'humidity_US', 'ozone_US', 'precip_US', 'pressure_US', 'sunrise_US', 'sunset_US', 'tMax_US', 'tMin_US', 'uv_US', 'wind_US']
# Global names ['cloud_Global', 'dew_Global', 'humidity_Global', 'ozone_Global', 'precip_Global', 'pressure_Global', 'sunrise_Global', 'sunset_Global', 'tMax_Global', 'tMin_Global', 'uv_Global', 'wind_Global']

# %%
# getting table info

# query = 'SELECT * FROM {}'.format(US_names[0])
# cursorObj.execute(query)

# the_table = cursorObj.fetchall()

# the_table

# %%
# adding dates to tables
# current last date is 8/12/20

for x in range(14, 32):
    
    day_str = str(x)
    date_str = '"8/' + day_str + '/20"'
    
    for y in US_names:
        
        add_str = 'ALTER TABLE {} ADD COLUMN {} text'.format(y, date_str)
        cursorObj.execute(add_str)
        print(add_str)
    
    for y in global_names:
        
        add_str = 'ALTER TABLE {} ADD COLUMN {} text'.format(y, date_str)
        cursorObj.execute(add_str)
        print(add_str)

# %%
# Reading API key

key_path = '/home/imants/gits/COVID-19/key.txt'

api_file = open(key_path, 'r')
API_KEY = api_file.read()
api_file.close()
API_KEY = API_KEY.strip()

API_KEY
# Out:
# 'fd67c61a3fdf164fff95f9fc3b05d06b'

# %%
# Creating API call function

import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

def call_api (lat, long, time):
    
    # Building the URL for the API get
    url = 'https://api.darksky.net/forecast/' + API_KEY + '/' + lat + "," + long + ',' + time
    url = url + '?exclude=currently,flags&units=si'

    # Getting the API call
    # using the retry error handling established above
    response = http.get(url)
    
    # Putting the API response into the JSON thing
    info = json.loads(response.content)
    #info = url
    
    return info

# %%
# update US locations

import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

# Code to increase number of retries on connection errors,
# and also to give it some time.
# Found on https://stackoverflow.com/questions/15431044/can-i-set-max-retries-for-requests-request
# And https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

s = requests.Session()

retries = Retry(total=30,
                backoff_factor=0.1,
                status_forcelist=[ 429, 500, 502, 503, 504 ],
                method_whitelist=["HEAD", "GET", "OPTIONS"])

adapter = HTTPAdapter(max_retries=retries)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)

# Dummy value in case of errors
dummy = '-1000'

# Making list of columns that need to be updated from prior update, above
columns_to_update = []

# Counting API calls
counter = 0

for x in range(13, 32):
    
    day_str = str(x)
    date_str = '"8/' + day_str + '/20"'
    columns_to_update.append(date_str)

for col_name in columns_to_update:
    
    tables = []
        
    for tab_name in US_names:
        
        query_string = 'SELECT Lat, "Long_", {} FROM {}'.format(col_name, tab_name)
        # print(query_string)
        cursorObj.execute(query_string)
        tables.append(cursorObj.fetchall())
        
        # names_test = cursorObj.execute(query_string).description
        # print(names_test[2][0], col_name)
        
    # print(len(tables[0]))
   
    # Create Unix time stamp out of the date column
    # stripping quotation marks from column name
    i = len(col_name)
    col_date = col_name[1:(i-1)]
    
    t = pd.to_datetime(col_date)
    t = int(t.value / 10**9)
    t = str(t)
    
    
    for y in range(len(tables[0])):
        
        latitude = str(tables[0][y][0])
        longitude = str(tables[0][y][1])
        
        # Calling API with latitude, longitude, and unix time
        info = call_api(latitude, longitude, t)
        
        print(counter)
        counter = counter + 1
        
        # print(info)
        print('Latitude: ', latitude, ', Longitude: ', longitude, ', Date: ', col_name)
        print('Unix time: ', t)
        
        
        # US names: [0: 'cloud_US', 1: 'dew_US', 2: 'humidity_US', 3: 'ozone_US', 4: 'precip_US', 5: 'pressure_US', 
        #           6: 'sunrise_US', 7: 'sunset_US', 8: 'tMax_US', 9: 'tMin_US', 10: uv_US', 11: 'wind_US']
       
        
        # getting values from the JSON response
        # adding error handling in case something is wrong with the JSON response
        try:

            # Making a variable to more easily acccess JSON response data
            easy_info = info['daily']['data'][0]

            # Reading the JSON data
            tMax = str(easy_info['temperatureHigh'])
            tMin = str(easy_info['temperatureLow'])
            hum = str(easy_info['humidity'] * 100)
            uvee = str(easy_info['uvIndex'])
            clouds = str(easy_info['cloudCover'] * 100)
            precip = str(easy_info['precipProbability'] * 100)
            dew = str(easy_info['dewPoint'])
            pressure = str(easy_info['pressure'])
            wind = str(easy_info['windSpeed'])
            ozone = str(easy_info['ozone'])
            sunrise = str(easy_info['sunriseTime'])
            sunset = str(easy_info['sunsetTime'])

        except:

            # Creating dummy values in case of error
            print('Error encountered')
            tMax = dummy
            tMin = dummy
            hum = dummy
            uvee = dummy
            clouds = dummy
            precip = dummy
            dew = dummy
            pressure = dummy
            wind = dummy
            ozone = dummy
            sunrise = dummy
            sunset = dummy

        
        where_str = 'Lat = {} AND Long_ = {}'.format(latitude, longitude)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('cloud_US', col_name, clouds, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('dew_US', col_name, dew, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('humidity_US', col_name, hum, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('ozone_US', col_name, ozone, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('precip_US', col_name, precip, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('pressure_US', col_name, pressure, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('sunrise_US', col_name, sunrise, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('sunset_US', col_name, sunset, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('tMax_US', col_name, tMax, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('tMin_US', col_name, tMin, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('uv_US', col_name, uvee, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('wind_US', col_name, wind, where_str)
        # cursorObj.execute(update_str)
        
        
        
        
        # print(iteration[y][2])
# test_string = 'SELECT Lat, "Long_", "8/13/20" FROM cloud_US'

# cursorObj.execute(test_string)

# the_table = cursorObj.fetchall()

#the_table[0]
#print(tables[0][0])
#names_test = tables[0].description

#print(names_test)
# Out:
# 0
# {'latitude': 32.53952745, 'longitude': -86.64408227, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Humid throughout the day.', 'icon': 'clear-day', 'data': [{'time': 1597208400, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0472, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 23.57, 'apparentTemperature': 24.49, 'dewPoint': 22.88, 'humidity': 0.96, 'pressure': 1016.2, 'windSpeed': 1.38, 'windGust': 2.98, 'windBearing': 241, 'cloudCover': 0.78, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.1}, {'time': 1597212000, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.05, 'apparentTemperature': 23.89, 'dewPoint': 22.26, 'humidity': 0.95, 'pressure': 1016.6, 'windSpeed': 1.23, 'windGust': 2, 'windBearing': 273, 'cloudCover': 0.78, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.8}, {'time': 1597215600, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 22.84, 'apparentTemperature': 23.7, 'dewPoint': 22.26, 'humidity': 0.97, 'pressure': 1016.2, 'windSpeed': 1.24, 'windGust': 2.41, 'windBearing': 258, 'cloudCover': 0.79, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284}, {'time': 1597219200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 22.69, 'apparentTemperature': 23.55, 'dewPoint': 22.2, 'humidity': 0.97, 'pressure': 1015.7, 'windSpeed': 1, 'windGust': 2.47, 'windBearing': 332, 'cloudCover': 0.64, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.6}, {'time': 1597222800, 'summary': 'Humid and Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0455, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.4, 'apparentTemperature': 23.28, 'dewPoint': 22.22, 'humidity': 0.99, 'pressure': 1015.4, 'windSpeed': 1.01, 'windGust': 2.58, 'windBearing': 285, 'cloudCover': 0.49, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.9}, {'time': 1597226400, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0.0357, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.04, 'apparentTemperature': 22.92, 'dewPoint': 22.04, 'humidity': 1, 'pressure': 1015.8, 'windSpeed': 0.63, 'windGust': 1.18, 'windBearing': 318, 'cloudCover': 0.26, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.7}, {'time': 1597230000, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0.0362, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.38, 'apparentTemperature': 23.23, 'dewPoint': 22.06, 'humidity': 0.98, 'pressure': 1016.3, 'windSpeed': 0.59, 'windGust': 0.9, 'windBearing': 82, 'cloudCover': 0.24, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284}, {'time': 1597233600, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0.0072, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 22.42, 'apparentTemperature': 23.26, 'dewPoint': 21.98, 'humidity': 0.97, 'pressure': 1017, 'windSpeed': 0.53, 'windGust': 0.77, 'windBearing': 111, 'cloudCover': 0.28, 'uvIndex': 0, 'visibility': 12.503, 'ozone': 283.5}, {'time': 1597237200, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.62, 'apparentTemperature': 24.53, 'dewPoint': 22.83, 'humidity': 0.95, 'pressure': 1017.4, 'windSpeed': 0.6, 'windGust': 0.92, 'windBearing': 126, 'cloudCover': 0.27, 'uvIndex': 1, 'visibility': 12.988, 'ozone': 283.5}, {'time': 1597240800, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0095, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 25.59, 'apparentTemperature': 26.55, 'dewPoint': 23.78, 'humidity': 0.9, 'pressure': 1017.4, 'windSpeed': 0.71, 'windGust': 1.14, 'windBearing': 202, 'cloudCover': 0.06, 'uvIndex': 3, 'visibility': 16.093, 'ozone': 283.7}, {'time': 1597244400, 'summary': 'Humid', 'icon': 'clear-day', 'precipInte ...
# Latitude:  32.53952745 , Longitude:  -86.64408227 , Date:  "8/13/20"
# Unix time:  1597276800
# 1
# {'latitude': 30.72774991, 'longitude': -87.72207058, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Humid throughout the day.', 'icon': 'rain', 'data': [{'time': 1597208400, 'summary': 'Humid and Overcast', 'icon': 'cloudy', 'precipIntensity': 0.8255, 'precipProbability': 0.13, 'precipType': 'rain', 'temperature': 23.4, 'apparentTemperature': 24.36, 'dewPoint': 23.1, 'humidity': 0.98, 'pressure': 1016.5, 'windSpeed': 2.01, 'windGust': 5.91, 'windBearing': 193, 'cloudCover': 0.96, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 286.2}, {'time': 1597212000, 'summary': 'Humid and Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0168, 'precipProbability': 0.04, 'precipType': 'rain', 'temperature': 22.36, 'apparentTemperature': 23.31, 'dewPoint': 22.36, 'humidity': 1, 'pressure': 1016.4, 'windSpeed': 1.45, 'windGust': 1.82, 'windBearing': 247, 'cloudCover': 0.48, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 286.4}, {'time': 1597215600, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 22.08, 'apparentTemperature': 23.06, 'dewPoint': 22.08, 'humidity': 1, 'pressure': 1016.2, 'windSpeed': 1.29, 'windGust': 1.58, 'windBearing': 297, 'cloudCover': 0.49, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.5}, {'time': 1597219200, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature':
 'uvIndex': 0, 'visibility': 16.093, 'ozone': 286.3}, {'time': 1597237200, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0086, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 24.3, 'apparentTemperature': 25.27, 'dewPoint': 23.5, 'humidity': 0.95, 'pressure': 1017.1, 'windSpeed': 0.57, 'windGust': 0.59, 'windBearing': 107, 'cloudCover': 0.17, 'uvIndex': 1, 'visibility': 16.093, 'ozone': 285}, {'time': 1597240800, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0576, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 26.74, 'apparentTemperature': 29.55, 'dewPoint': 23.95, 'humidity': 0.85, 'pressure': 1017.2, 'windSpeed': 0.63, 'windGust': 1.6, 'windBearing': 245, 'cloudCover': 0.13, 'uvIndex': 3, ' ...
# Latitude:  32.99642064 , Longitude:  -87.12511459999996 , Date:  "8/13/20"
# Unix time:  1597276800
# 4
# {'latitude': 33.98210918, 'longitude': -86.56790593, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Humid throughout the day.', 'icon': 'rain', 'data': [{'time': 1597208400, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0.0161, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 24.79, 'apparentTemperature': 25.72, 'dewPoint': 23.41, 'humidity': 0.92, 'pressure': 1015.9, 'windSpeed': 1.18, 'windGust': 1.59, 'windBearing': 202, 'cloudCover': 0.05, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 286.7}, {'time': 1597212000, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0.0053, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 24.08, 'apparentTemperature': 25.03, 'dewPoint': 23.28, 'humidity': 0.95, 'pressure': 1016.3, 'windSpeed': 1.49, 'windGust': 2.36, 'windBearing': 206, 'cloudCover': 0.03, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.6}, {'time': 1597215600, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.72, 'apparentTemperature': 24.65, 'dewPoint': 23.04, 'humidity': 0.96, 'pressure': 1016, 'windSpeed': 1.48, 'windGust': 4.15, 'windBearing': 187, 'cloudCover': 0.15, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 283}, {'time': 1597219200, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.36, 'apparentTemperature': 24.29, 'dewPoint': 22.87, 'humidity': 0.97, 'pressure': 1015.6, 'windSpeed': 1.43, 'windGust': 3.84, 'windBearing': 214, 'cloudCover': 0.21, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 282.6}, {'time': 1597222800, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0.0436, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 22.95, 'apparentTemperature': 23.85, 'dewPoint': 22.55, 'humidity': 0.98, 'pressure': 1015.4, 'windSpeed': 1.06, 'windGust': 3.28, 'windBearing': 251, 'cloudCover': 0.28, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 282.3}, {'time': 1597226400, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0.0373, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.52, 'apparentTemperature': 23.42, 'dewPoint': 22.36, 'humidity': 0.99, 'pressure': 1015.8, 'windSpeed': 0.78, 'windGust': 1.03, 'windBearing': 316, 'cloudCover': 0.25, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 282}, {'time': 1597230000, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0.0461, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.72, 'apparentTemperature': 23.57, 'dewPoint': 22.19, 'humidity': 0.97, 'pressure': 1016.3, 'windSpeed': 0.72, 'windGust': 0.83, 'windBearing': 152, 'cloudCover': 0.26, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 281.8}, {'time': 1597233600, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0099, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 22.98, 'apparentTemperature': 23.84, 'dewPoint': 22.36, 'humidity': 0.96, 'pressure': 1016.8, 'windSpeed': 0.49, 'windGust': 0.66, 'windBearing': 170, 'cloudCover': 0.13, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 281.6}, {'time': 1597237200, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0991, 'precipProbability': 0.05, 'precipType': 'rain', 'temperature': 24.09, 'apparentTemperature': 25.05, 'dewPoint': 23.36, 'humidity': 0.96, 'pressure': 1016.9, 'windSpeed': 0.68, 'windGust': 1.06, 'windBearing': 114, 'cloudCover': 0.13, 'uvIndex': 1, 'visibility': 16.093, 'ozone': 281.4}, {'time': 1597240800, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.128, 'precipProbability': 0.05, 'precipType': 'rain', 'temperature': 26.17, 'apparentTemperature': 28.47, 'dewPoint': 24.34, 'humidity': 0.9, 'pressure': 1016.8, 'windSpeed': 0.81, 'windGust': 1.27, 'windBearing': 195, 'cloudCover': 0.13, 'uvIndex': 3, 'visibility': 16.093, 'ozone': 280.9}, {'time': 1597244400, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.1679, 'precipProbability': 0.04, 'precipT ...
# Latitude:  33.98210918 , Longitude:  -86.56790593 , Date:  "8/13/20"
# Unix time:  1597276800
# 5
# {'latitude': 32.10030533, 'longitude': -85.71265535, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Humid throughout the day.', 'icon': 'rain', 'data': [{'time': 1597208400, 'summary': 'Humid and Overcast', 'icon': 'cloudy', 'precipIntensity': 0.0196, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 23.71, 'apparentTemperature': 24.68, 'dewPoint': 23.25, 'humidity': 0.97, 'pressure': 1016.3, 'windSpeed': 1.57, 'windGust': 3.76, 'windBearing': 268, 'cloudCover': 0.94, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 288.3}, {'time': 1597212000, 'summary': 'Humid and Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.23, 'apparentTemperature': 24.11, 'dewPoint': 22.49, 'humidity': 0.96, 'pressure': 1016.6, 'windSpeed': 1.34, 'windGust': 2.44, 'windBearing': 284, 'cloudCover': 0.47, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 288.8}, {'time': 1597215600, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0051, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.79, 'apparentTemperature': 23.63, 'dewPoint': 22.11, 'humidity': 0.96, 'pressure': 1016.5, 'windSpeed': 1.29, 'windGust': 1.74, 'windBearing': 327, 'cloudCover': 0.39, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 286.8}, {'time': 1597219200, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0068, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.41, 'apparentTemperature': 23.24, 'dewPoint': 21.87, 'humidity': 0.97, 'pressure': 1016.1, 'windSpeed': 1.15, 'windGust': 1.64, 'windBearing': 15, 'cloudCover': 0.33, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.8}, {'time': 1597222800, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0.0495, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 21.99, 'apparentTemperature': 22.8, 'dewPoint': 21.61, 'humidity': 0.98, 'pressure': 1015.7, 'windSpeed': 0.82, 'windGust': 1.27, 'windBearing': 270, 'cloudCover': 0.31, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285}, {'time': 1597226400, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0423, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 21.72, 'apparentTemperature': 22.53, 'dewPoint': 21.55, 'humidity': 0.99, 'pressure': 1016.1, 'windSpeed': 0.82, 'windGust': 1.04, 'windBearing': 285, 'cloudCover': 0.33, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.7}, {'time': 1597230000, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0471, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 21.98, 'apparentTemperature': 22.75, 'dewPoint': 21.37, 'humidity': 0.96, 'pressure': 1016.6, 'windSpeed': 0.85, 'windGust': 0.95, 'windBearing': 238, 'cloudCover': 0.34, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.6}, {'time': 1597233600, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0.0168, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 22.2, 'apparentTemperature': 22.98, 'dewPoint': 21.51, 'humidity': 0.96, 'pressure': 1017.1, 'windSpeed': 0.75, 'windGust': 1.02, 'windBearing': 250, 'cloudCover': 0.22, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.4}, {'time': 1597237200, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0.0241, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 23.77, 'apparentTemperature': 24.57, 'dewPoint': 22.18, 'humidity': 0.91, 'pressure': 1017.5, 'windSpeed': 0.83, 'windGust': 1.64, 'windBearing': 194, 'cloudCover': 0.16, 'uvIndex': 1, 'visibility': 16.093, 'ozone': 283.9}, {'time': 1597240800, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0283, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 26.37, 'apparentTemperature': 28.43, 'dewPoint': 22.73, 'humidity': 0.8, 'pressure': 1017.5, 'windSpeed': 0.91, 'windGust': 1.98, 'windBearing': 337, 'cloudCover': 0.08, 'uvIndex': 3, 'visibility': 16.093, 'ozone': 28 ...
# Latitude:  32.10030533 , Longitude:  -85.71265535 , Date:  "8/13/20"
# Unix time:  1597276800
# 6
# {'latitude': 31.75300095, 'longitude': -86.68057478, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Rain in the evening.', 'icon': 'rain', 'data': [{'time': 1597208400, 'summary': 'Humid and Overcast', 'icon': 'cloudy', 'precipIntensity': 0.0211, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 23.36, 'apparentTemperature': 24.19, 'dewPoint': 22.25, 'humidity': 0.93, 'pressure': 1016.5, 'windSpeed': 1.77, 'windGust': 6.27, 'windBearing': 229, 'cloudCover': 0.95, 'uvIndex': 0, 'visibility': 16.093, 'ozone':
 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 23.15, 'apparentTemperature': 24.14, 'dewPoint': 23.15, 'humidity': 1, 'pressure': 1016.6, 'windSpeed': 0.6, 'windGust': 0.75, 'windBearing': 321, 'cloudCover': 0.13, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.7}, {'time': 1597237200, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.2152, 'precipProbability': 0.05, 'precipType': 'rain', 'temperature': 24.87, 'apparentTemperature': 25.94, 'dewPoint': 24.35, 'humidity': 0.97, 'pressure': 1016.9, 'windSpeed': 0.63, 'windGust': 0.87, 'windBearing': 7, 'cloudCover': 0.01, 'uvIndex': 1, 'visibility': 16.093, 'ozone': 283.9}, {'time': 1597240800, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.1223, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 26.92, 'apparentTemperature': 31.34, 'dewPoint': 25.64, 'humidity': 0.93, 'pressure': 1016.8, 'windSpeed': 0.64, 'windGust': 1.29, 'windBearing': 72, 'cloudCover': 0.03, 'uvIndex': 3, 'visibility': 16.093, 'ozone': 282.6}, {'time': 1597244400, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0628 ...
# Latitude:  34.17805983 , Longitude:  -85.60638968 , Date:  "8/13/20"
# Unix time:  1597276800
# 10
# {'latitude': 32.85044126, 'longitude': -86.7173256, 'timezone': 'America/Chicago', 'hourly': {'summary': 'Humid throughout the day.', 'icon': 'rain', 'data': [{'time': 1597208400, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0632, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 23.77, 'apparentTemperature': 24.71, 'dewPoint': 23.08, 'humidity': 0.96, 'pressure': 1016.2, 'windSpeed': 1.6, 'windGust': 5.11, 'windBearing': 212, 'cloudCover': 0.76, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.6}, {'time': 1597212000, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0072, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 23.22, 'apparentTemperature': 24.1, 'dewPoint': 22.5, 'humidity': 0.96, 'pressure': 1016.5, 'windSpeed': 1.36, 'windGust': 2.85, 'windBearing': 237, 'cloudCover': 0.7, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.9}, {'time': 1597215600, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 22.98, 'apparentTemperature': 23.88, 'dewPoint': 22.55, 'humidity': 0.97, 'pressure': 1016.3, 'windSpeed': 1.35, 'windGust': 4.38, 'windBearing': 260, 'cloudCover': 0.72, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 283.7}, {'time': 1597219200, 'summary': 'Humid and Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 22.72, 'apparentTemperature': 23.61, 'dewPoint': 22.4, 'humidity': 0.98, 'pressure': 1015.8, 'windSpeed': 1.02, 'windGust': 3.46, 'windBearing': 265, 'cloudCover': 0.61, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 283.8}, {'time': 1597222800, 'summary': 'Humid and Partly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0458, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.5, 'apparentTemperature': 23.42, 'dewPoint': 22.5, 'humidity': 1, 'pressure': 1015.4, 'windSpeed': 0.98, 'windGust': 3.12, 'windBearing': 279, 'cloudCover': 0.42, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.1}, {'time': 1597226400, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0.0351, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.15, 'apparentTemperature': 23.07, 'dewPoint': 22.15, 'humidity': 1, 'pressure': 1015.9, 'windSpeed': 0.65, 'windGust': 1.42, 'windBearing': 281, 'cloudCover': 0.21, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 284.6}, {'time': 1597230000, 'summary': 'Humid', 'icon': 'clear-night', 'precipIntensity': 0.0351, 'precipProbability': 0.02, 'precipType': 'rain', 'temperature': 22.54, 'apparentTemperature': 23.43, 'dewPoint': 22.34, 'humidity': 0.99, 'pressure': 1016.4, 'windSpeed': 0.55, 'windGust': 0.78, 'windBearing': 161, 'cloudCover': 0.19, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 285.3}, {'time': 1597233600, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.0077, 'precipProbability': 0.01, 'precipType': 'rain', 'temperature': 22.63, 'apparentTemperature': 23.5, 'dewPoint': 22.26, 'humidity': 0.98, 'pressure': 1017, 'windSpeed': 0.52, 'windGust': 0.64, 'windBearing': 128, 'cloudCover': 0.21, 'uvIndex': 0, 'visibility': 15.817, 'ozone': 285.6}, {'time': 1597237200, 'summary': 'Humid', 'icon': 'clear-day', 'precipIntensity': 0.
, Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 927
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.99978709 , Longitude:  -101.7921066 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 928
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.19175361 , Longitude:  -98.07578384 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 929
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.04293782 , Longitude:  -97.42747573 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 930
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.5620394 , Longitude:  -100.8710738 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 931
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.08780079 , Longitude:  -99.89829881 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 932
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  39.41673394 , Longitude:  -95.79356799 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 933
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  39.2347941 , Longitude:  -95.38289232 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 934
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  39.78470589 , Longitude:  -98.21820662 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 935
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.88548175 , Longitude:  -94.82250877 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 936
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.00017981 , Longitude:  -101.321681 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 937
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.55909527 , Longitude:  -98.13638678 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 938
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.55848695 , Longitude:  -99.2856537 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 939
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  37.19113093 , Longitude:  -95.29849679 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 940
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.48119447 , Longitude:  -100.4660754 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 941
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  39.20183497 , Longitude:  -95.03620809 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 942
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  39.04549684 , Longitude:  -98.20756994 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 943
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.21267844 , Longitude:  -94.84254089 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 944
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.91735806 , Longitude:  -101.148475 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 945
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.45576156 , Longitude:  -96.15275715 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# 946
# {'code': 403, 'error': 'daily usage limit exceeded'}
# Latitude:  38.35855394 , Longitude:  -97.0985251 , Date:  "8/13/20"
# Unix time:  1597276800
# Error encountered
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-20f632205845> in <module>
#      74
#      75         # Calling API with latitude, longitude, and unix time
# ---> 76         info = call_api(latitude, longitude, t)
#      77
#      78         print(counter)
#
# <ipython-input-11-9ae815431227> in call_api(lat, long, time)
#      15     # Getting the API call
#      16     # using the retry error handling established above
# ---> 17     response = http.get(url)
#      18
#      19     # Putting the API response into the JSON thing
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# test cell

import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

# Code to increase number of retries on connection errors,
# and also to give it some time.
# Found on https://stackoverflow.com/questions/15431044/can-i-set-max-retries-for-requests-request
# And https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

s = requests.Session()

retries = Retry(total=30,
                backoff_factor=0.1,
                status_forcelist=[ 429, 500, 502, 503, 504 ],
                method_whitelist=["HEAD", "GET", "OPTIONS"])

adapter = HTTPAdapter(max_retries=retries)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)


# test API call
def call_api (lat, long, time):
    
    # Building the URL for the API get
    url = 'https://api.darksky.net/forecast/' + API_KEY + '/' + lat + "," + long + ',' + time
    url = url + '?exclude=currently,flags&units=si'

    # Getting the API call
    # using the retry error handling established above
    # response = http.get(url)
    
    # Putting the API response into the JSON thing
    #info = json.loads(response.content)
    info = url
    
    return info


# Dummy value in case of errors
dummy = '-1000'

# Making list of columns that need to be updated from prior update, above
columns_to_update = []

# Counting API calls
counter = 0

for x in range(13, 32):
    
    day_str = str(x)
    date_str = '"8/' + day_str + '/20"'
    columns_to_update.append(date_str)

for col_name in columns_to_update:
    
    tables = []
        
    for tab_name in US_names:
        
        query_string = 'SELECT Lat, "Long_", {} FROM {}'.format(col_name, tab_name)
        # print(query_string)
        cursorObj.execute(query_string)
        tables.append(cursorObj.fetchall())
        
        # names_test = cursorObj.execute(query_string).description
        # print(names_test[2][0], col_name)
        
    # print(len(tables[0]))
   
    # Create Unix time stamp out of the date column
    # stripping quotation marks from column name
    i = len(col_name)
    col_date = col_name[1:(i-1)]
    
    t = pd.to_datetime(col_date)
    t = int(t.value / 10**9)
    t = str(t)
    
    
    for y in range(len(tables[0])):
        
        latitude = str(tables[0][y][0])
        longitude = str(tables[0][y][1])
        
        # Calling API with latitude, longitude, and unix time
        info = call_api(latitude, longitude, t)
        
        print(counter)
        counter = counter + 1
        
        # print(info)
        print('Latitude: ', latitude, ', Longitude: ', longitude, ', Date: ', col_name)
        print('Unix time: ', t)
        
        
        # US names: [0: 'cloud_US', 1: 'dew_US', 2: 'humidity_US', 3: 'ozone_US', 4: 'precip_US', 5: 'pressure_US', 
        #           6: 'sunrise_US', 7: 'sunset_US', 8: 'tMax_US', 9: 'tMin_US', 10: uv_US', 11: 'wind_US']
       
        
        # getting values from the JSON response
        # adding error handling in case something is wrong with the JSON response
        try:

            # Making a variable to more easily acccess JSON response data
            easy_info = info['daily']['data'][0]

            # Reading the JSON data
            tMax = str(easy_info['temperatureHigh'])
            tMin = str(easy_info['temperatureLow'])
            hum = str(easy_info['humidity'] * 100)
            uvee = str(easy_info['uvIndex'])
            clouds = str(easy_info['cloudCover'] * 100)
            precip = str(easy_info['precipProbability'] * 100)
            dew = str(easy_info['dewPoint'])
            pressure = str(easy_info['pressure'])
            wind = str(easy_info['windSpeed'])
            ozone = str(easy_info['ozone'])
            sunrise = str(easy_info['sunriseTime'])
            sunset = str(easy_info['sunsetTime'])

        except:

            # Creating dummy values in case of error
            print('Error encountered')
            tMax = dummy
            tMin = dummy
            hum = dummy
            uvee = dummy
            clouds = dummy
            precip = dummy
            dew = dummy
            pressure = dummy
            wind = dummy
            ozone = dummy
            sunrise = dummy
            sunset = dummy

        
        where_str = 'Lat = {} AND Long_ = {}'.format(latitude, longitude)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('cloud_US', col_name, clouds, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('dew_US', col_name, dew, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('humidity_US', col_name, hum, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('ozone_US', col_name, ozone, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('precip_US', col_name, precip, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('pressure_US', col_name, pressure, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('sunrise_US', col_name, sunrise, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('sunset_US', col_name, sunset, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('tMax_US', col_name, tMax, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('tMin_US', col_name, tMin, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('uv_US', col_name, uvee, where_str)
        # cursorObj.execute(update_str)
        
        update_str = 'UPDATE {} SET {} = {} WHERE {}'.format('wind_US', col_name, wind, where_str)
        # cursorObj.execute(update_str)
        
        
        
        
        # print(iteration[y][2])
# test_string = 'SELECT Lat, "Long_", "8/13/20" FROM cloud_US'

# cursorObj.execute(test_string)

# the_table = cursorObj.fetchall()

#the_table[0]
#print(tables[0][0])
#names_test = tables[0].description

#print(names_test)

# %%
# temporary home for this code
# adding error handling in case something is wrong with the JSON response
        try:

            # Making a variable to more easily acccess JSON response data
            easy_info = info['daily']['data'][0]

            # Reading the JSON data
            tMax = easy_info['temperatureHigh']
            tMin = easy_info['temperatureLow']
            hum = easy_info['humidity'] * 100
            uvee = easy_info['uvIndex']
            clouds = easy_info['cloudCover'] * 100
            precip = easy_info['precipProbability'] * 100
            dew = easy_info['dewPoint']
            pressure = easy_info['pressure']
            wind = easy_info['windSpeed']
            ozone = easy_info['ozone']
            sunrise = easy_info['sunriseTime']
            sunset = easy_info['sunsetTime']

        except:

            # Creating dummy values in case of error
            print('Error encountered')
            tMax = dummy
            tMin = dummy
            hum = dummy
            uvee = dummy
            clouds = dummy
            precip = dummy
            dew = dummy
            pressure = dummy
            wind = dummy
            ozone = dummy
            sunrise = dummy
            sunset = dummy

# %%
for x in range(len(the_table)):
    print(x)

# %%
# close database connection

con.close()
