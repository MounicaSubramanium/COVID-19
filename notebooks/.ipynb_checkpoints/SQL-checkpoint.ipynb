# %% [markdown]
# Using SQL to update weather data

# %%
# sqlite3 library to run operations on the database
import sqlite3

gen_path = '/home/imants/gits/COVID-19/'

db_path = gen_path + 'sql/weather.db'

# connecting to the weather database
con = sqlite3.connect(db_path)

# establishing database cursor
cursorObj = con.cursor()

# %%
# Getting table names

import pandas as pd

table_names = cursorObj.execute("SELECT name FROM sqlite_master WHERE type='table';")

table_names = table_names.fetchall()

# Taking the table names that were fetched, and making a usable lists out of the values.

US_names = []
global_names = []

for x in range(len(table_names)):
    if (table_names[x][0][-2:] == 'US'):
        US_names.append(table_names[x][0])
        
    else:
        global_names.append(table_names[x][0])
        
 
print('US names', US_names)

print('Global names', global_names)
# Out:
# US names ['cloud_US', 'dew_US', 'humidity_US', 'ozone_US', 'precip_US', 'pressure_US', 'sunrise_US', 'sunset_US', 'tMax_US', 'tMin_US', 'uv_US', 'wind_US']
# Global names ['cloud_Global', 'dew_Global', 'humidity_Global', 'ozone_Global', 'precip_Global', 'pressure_Global', 'sunrise_Global', 'sunset_Global', 'tMax_Global', 'tMin_Global', 'uv_Global', 'wind_Global']

# %%
# getting table info

# query = 'SELECT * FROM {}'.format(US_names[0])
# cursorObj.execute(query)

# the_table = cursorObj.fetchall()

# the_table

# %%
# adding dates to tables
# current last date is 8/12/20

for x in range(14, 32):
    
    day_str = str(x)
    date_str = '"8/' + day_str + '/20"'
    
    for y in US_names:
        
        add_str = 'ALTER TABLE {} ADD COLUMN {} text'.format(y, date_str)
        cursorObj.execute(add_str)
        print(add_str)
    
    for y in global_names:
        
        add_str = 'ALTER TABLE {} ADD COLUMN {} text'.format(y, date_str)
        cursorObj.execute(add_str)
        print(add_str)
# Out:
# ALTER TABLE cloud_US ADD COLUMN "8/14/20" text
# ALTER TABLE dew_US ADD COLUMN "8/14/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/14/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/14/20" text
# ALTER TABLE precip_US ADD COLUMN "8/14/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/14/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/14/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/14/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/14/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/14/20" text
# ALTER TABLE uv_US ADD COLUMN "8/14/20" text
# ALTER TABLE wind_US ADD COLUMN "8/14/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/15/20" text
# ALTER TABLE dew_US ADD COLUMN "8/15/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/15/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/15/20" text
# ALTER TABLE precip_US ADD COLUMN "8/15/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/15/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/15/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/15/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/15/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/15/20" text
# ALTER TABLE uv_US ADD COLUMN "8/15/20" text
# ALTER TABLE wind_US ADD COLUMN "8/15/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/16/20" text
# ALTER TABLE dew_US ADD COLUMN "8/16/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/16/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/16/20" text
# ALTER TABLE precip_US ADD COLUMN "8/16/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/16/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/16/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/16/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/16/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/16/20" text
# ALTER TABLE uv_US ADD COLUMN "8/16/20" text
# ALTER TABLE wind_US ADD COLUMN "8/16/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/17/20" text
# ALTER TABLE dew_US ADD COLUMN "8/17/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/17/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/17/20" text
# ALTER TABLE precip_US ADD COLUMN "8/17/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/17/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/17/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/17/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/17/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/17/20" text
# ALTER TABLE uv_US ADD COLUMN "8/17/20" text
# ALTER TABLE wind_US ADD COLUMN "8/17/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/18/20" text
# ALTER TABLE dew_US ADD COLUMN "8/18/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/18/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/18/20" text
# ALTER TABLE precip_US ADD COLUMN "8/18/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/18/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/18/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/18/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/18/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/18/20" text
# ALTER TABLE uv_US ADD COLUMN "8/18/20" text
# ALTER TABLE wind_US ADD COLUMN "8/18/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/19/20" text
# ALTER TABLE dew_US ADD COLUMN "8/19/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/19/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/19/20" text
# ALTER TABLE precip_US ADD COLUMN "8/19/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/19/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/19/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/19/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/19/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/19/20" text
# ALTER TABLE uv_US ADD COLUMN "8/19/20" text
# ALTER TABLE wind_US ADD COLUMN "8/19/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/20/20" text
# ALTER TABLE dew_US ADD COLUMN "8/20/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/20/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/20/20" text
# ALTER TABLE precip_US ADD COLUMN "8/20/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/20/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/20/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/20/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/20/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/20/20" text
# ALTER TABLE uv_US ADD COLUMN "8/20/20" text
# ALTER TABLE wind_US ADD COLUMN "8/20/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/21/20" text
# ALTER TABLE dew_US ADD COLUMN "8/21/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/21/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/21/20" text
# ALTER TABLE precip_US ADD COLUMN "8/21/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/21/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/21/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/21/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/21/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/21/20" text
# ALTER TABLE uv_US ADD COLUMN "8/21/20" text
# ALTER TABLE wind_US ADD COLUMN "8/21/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/22/20" text
# ALTER TABLE dew_US ADD COLUMN "8/22/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/22/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/22/20" text
# ALTER TABLE precip_US ADD COLUMN "8/22/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/22/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/22/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/22/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/22/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/22/20" text
# ALTER TABLE uv_US ADD COLUMN "8/22/20" text
# ALTER TABLE wind_US ADD COLUMN "8/22/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/23/20" text
# ALTER TABLE dew_US ADD COLUMN "8/23/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/23/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/23/20" text
# ALTER TABLE precip_US ADD COLUMN "8/23/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/23/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/23/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/23/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/23/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/23/20" text
# ALTER TABLE uv_US ADD COLUMN "8/23/20" text
# ALTER TABLE wind_US ADD COLUMN "8/23/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/24/20" text
# ALTER TABLE dew_US ADD COLUMN "8/24/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/24/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/24/20" text
# ALTER TABLE precip_US ADD COLUMN "8/24/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/24/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/24/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/24/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/24/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/24/20" text
# ALTER TABLE uv_US ADD COLUMN "8/24/20" text
# ALTER TABLE wind_US ADD COLUMN "8/24/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/25/20" text
# ALTER TABLE dew_US ADD COLUMN "8/25/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/25/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/25/20" text
# ALTER TABLE precip_US ADD COLUMN "8/25/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/25/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/25/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/25/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/25/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/25/20" text
# ALTER TABLE uv_US ADD COLUMN "8/25/20" text
# ALTER TABLE wind_US ADD COLUMN "8/25/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/26/20" text
# ALTER TABLE dew_US ADD COLUMN "8/26/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/26/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/26/20" text
# ALTER TABLE precip_US ADD COLUMN "8/26/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/26/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/26/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/26/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/26/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/26/20" text
# ALTER TABLE uv_US ADD COLUMN "8/26/20" text
# ALTER TABLE wind_US ADD COLUMN "8/26/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/27/20" text
# ALTER TABLE dew_US ADD COLUMN "8/27/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/27/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/27/20" text
# ALTER TABLE precip_US ADD COLUMN "8/27/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/27/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/27/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/27/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/27/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/27/20" text
# ALTER TABLE uv_US ADD COLUMN "8/27/20" text
# ALTER TABLE wind_US ADD COLUMN "8/27/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/28/20" text
# ALTER TABLE dew_US ADD COLUMN "8/28/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/28/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/28/20" text
# ALTER TABLE precip_US ADD COLUMN "8/28/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/28/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/28/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/28/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/28/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/28/20" text
# ALTER TABLE uv_US ADD COLUMN "8/28/20" text
# ALTER TABLE wind_US ADD COLUMN "8/28/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/29/20" text
# ALTER TABLE dew_US ADD COLUMN "8/29/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/29/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/29/20" text
# ALTER TABLE precip_US ADD COLUMN "8/29/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/29/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/29/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/29/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/29/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/29/20" text
# ALTER TABLE uv_US ADD COLUMN "8/29/20" text
# ALTER TABLE wind_US ADD COLUMN "8/29/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/30/20" text
# ALTER TABLE dew_US ADD COLUMN "8/30/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/30/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/30/20" text
# ALTER TABLE precip_US ADD COLUMN "8/30/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/30/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/30/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/30/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/30/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/30/20" text
# ALTER TABLE uv_US ADD COLUMN "8/30/20" text
# ALTER TABLE wind_US ADD COLUMN "8/30/20" text
# ALTER TABLE cloud_US ADD COLUMN "8/31/20" text
# ALTER TABLE dew_US ADD COLUMN "8/31/20" text
# ALTER TABLE humidity_US ADD COLUMN "8/31/20" text
# ALTER TABLE ozone_US ADD COLUMN "8/31/20" text
# ALTER TABLE precip_US ADD COLUMN "8/31/20" text
# ALTER TABLE pressure_US ADD COLUMN "8/31/20" text
# ALTER TABLE sunrise_US ADD COLUMN "8/31/20" text
# ALTER TABLE sunset_US ADD COLUMN "8/31/20" text
# ALTER TABLE tMax_US ADD COLUMN "8/31/20" text
# ALTER TABLE tMin_US ADD COLUMN "8/31/20" text
# ALTER TABLE uv_US ADD COLUMN "8/31/20" text
# ALTER TABLE wind_US ADD COLUMN "8/31/20" text

# %%
# Reading API key

key_path = '/home/imants/gits/COVID-19/key.txt'

api_file = open(key_path, 'r')
API_KEY = api_file.read()
api_file.close()
API_KEY = API_KEY.strip()

API_KEY
# Out:
# '4c660453101c9bb8a7f8360c95eaf4c1'

# %%
# update US locations

import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime as dt

# Code to increase number of retries on connection errors,
# and also to give it some time.
# Found on https://stackoverflow.com/questions/15431044/can-i-set-max-retries-for-requests-request
# And https://findwork.dev/blog/advanced-usage-python-requests-timeouts-retries-hooks/

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

s = requests.Session()

retries = Retry(total=30,
                backoff_factor=0.1,
                status_forcelist=[ 429, 500, 502, 503, 504 ],
                method_whitelist=["HEAD", "GET", "OPTIONS"])

adapter = HTTPAdapter(max_retries=retries)
http = requests.Session()
http.mount("https://", adapter)
http.mount("http://", adapter)

# Making list of columns that need to be updated from prior update, above

columns_to_update = []

for x in range(13, 32):
    
    day_str = str(x)
    date_str = '"8/' + day_str + '/20"'
    columns_to_update.append(date_str)

for y in columns_to_update:
    
    query_string = 'SELECT Lat, "Long_", {} FROM {}'.format(y, US_names[0])
    print(query_string)
    
test_string = 'SELECT Lat, "Long_", "8/13/20" FROM cloud_US'

cursorObj.execute(test_string)

the_table = cursorObj.fetchall()

the_table[0]
# Out:
# SELECT Lat, "Long_", "8/13/20" FROM cloud_US
# SELECT Lat, "Long_", "8/14/20" FROM cloud_US
# SELECT Lat, "Long_", "8/15/20" FROM cloud_US
# SELECT Lat, "Long_", "8/16/20" FROM cloud_US
# SELECT Lat, "Long_", "8/17/20" FROM cloud_US
# SELECT Lat, "Long_", "8/18/20" FROM cloud_US
# SELECT Lat, "Long_", "8/19/20" FROM cloud_US
# SELECT Lat, "Long_", "8/20/20" FROM cloud_US
# SELECT Lat, "Long_", "8/21/20" FROM cloud_US
# SELECT Lat, "Long_", "8/22/20" FROM cloud_US
# SELECT Lat, "Long_", "8/23/20" FROM cloud_US
# SELECT Lat, "Long_", "8/24/20" FROM cloud_US
# SELECT Lat, "Long_", "8/25/20" FROM cloud_US
# SELECT Lat, "Long_", "8/26/20" FROM cloud_US
# SELECT Lat, "Long_", "8/27/20" FROM cloud_US
# SELECT Lat, "Long_", "8/28/20" FROM cloud_US
# SELECT Lat, "Long_", "8/29/20" FROM cloud_US
# SELECT Lat, "Long_", "8/30/20" FROM cloud_US
# SELECT Lat, "Long_", "8/31/20" FROM cloud_US
# ('32.53952745', '-86.64408227', None)

# %%
# close database connection

con.close()
